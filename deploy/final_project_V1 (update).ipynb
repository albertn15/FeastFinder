# %% [markdown]
# # **Final Project Group 2**
#
# Contributor :
# 1. Akbar
# 2. Albert
# 3. Ari
# 4. Titan

# %% [markdown]
# ---

# %% [markdown]
# # i. Import Libraries

# %%
# library dataframe
import pandas as pd
# library olah data numerical
import numpy as np

# Library Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from wordcloud import WordCloud

import re
import nltk
import demoji
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer


from pprint import pprint
# To Ignore Warning
import warnings
warnings.filterwarnings("ignore")

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
demoji.download_codes()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ---

# %% [markdown]
# # ii. Data Loading

# %%
df = pd.read_csv('TripAdvisor_RestauarantRecommendation.csv')
df.head()
# Out:
#                             Name       Street Address  \
# 0  Betty Lou's Seafood and Grill     318 Columbus Ave
# 1              Coach House Diner        55 State Rt 4
# 2               Table Talk Diner  2521 South Rd Ste C
# 3                    Sixty Vines     3701 Dallas Pkwy
# 4                   The Clam Bar    3914 Brewerton Rd
#
#                        Location                                          Type  \
# 0  San Francisco, CA 94133-3908   Seafood, Vegetarian Friendly, Vegan Options
# 1     Hackensack, NJ 07601-6337          Diner, American, Vegetarian Friendly
# 2   Poughkeepsie, NY 12601-5476          American, Diner, Vegetarian Friendly
# 3          Plano, TX 75093-7777       American, Wine Bar, Vegetarian Friendly
# 4            Syracuse, NY 13212                        American, Bar, Seafood
#
#             Reviews No of Reviews  \
# 0  4.5 of 5 bubbles   243 reviews
# 1    4 of 5 bubbles    84 reviews
# 2    4 of 5 bubbles   256 reviews
# 3  4.5 of 5 bubbles   235 reviews
# 4    4 of 5 bubbles   285 reviews
#
#                                             Comments   Contact Number  \
# 0                                                NaN  +1 415-757-0569
# 1  Both times we were there very late, after 11 P...  +1 201-488-4999
# 2  Waitress was very friendly but a little pricey...  +1 845-849-2839
# 3  Not sure why I went there for the second time....  +1 469-620-8463
# 4  Doesn't look like much from the outside but wa...  +1 315-458-1662
#
#                                     Trip_advisor Url  \
# 0  https://www.tripadvisor.com//Restaurant_Review...
# 1  https://www.tripadvisor.com//Restaurant_Review...
# 2  https://www.tripadvisor.com//Restaurant_Review...
# 3  https://www.tripadvisor.com//Restaurant_Review...
# 4  https://www.tripadvisor.com//Restaurant_Review...
#
#                                         Menu Price_Range
# 0               Check The Website for a Menu    $$ - $$$
# 1               Check The Website for a Menu    $$ - $$$
# 2  http://tabletalkdiner.com/menu/breakfast/    $$ - $$$
# 3      https://sixtyvines.com/menu/plano-tx/    $$ - $$$
# 4               Check The Website for a Menu    $$ - $$$

# %%
# Cek Data Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3062 entries, 0 to 3061
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              3062 non-null   object
#  1   Street Address    3062 non-null   object
#  2   Location          3062 non-null   object
#  3   Type              3049 non-null   object
#  4   Reviews           3062 non-null   object
#  5   No of Reviews     3062 non-null   object
#  6   Comments          2447 non-null   object
#  7   Contact Number    3062 non-null   object
#  8   Trip_advisor Url  3062 non-null   object
#  9   Menu              3062 non-null   object
#  10  Price_Range       3062 non-null   object
# dtypes: object(11)
# memory usage: 263.3+ KB

# %% [markdown]
# Penjelasan:
# - Ada bebrapa kolom yang null value
# - 3062 baris dan 11 kolom

# %% [markdown]
# **Drop data yang tidak relevant**

# %%
df.drop(['Contact Number', 'Trip_advisor Url','Menu'], axis=1, inplace=True)
df.head()
# Out:
#                             Name       Street Address  \
# 0  Betty Lou's Seafood and Grill     318 Columbus Ave
# 1              Coach House Diner        55 State Rt 4
# 2               Table Talk Diner  2521 South Rd Ste C
# 3                    Sixty Vines     3701 Dallas Pkwy
# 4                   The Clam Bar    3914 Brewerton Rd
#
#                        Location                                          Type  \
# 0  San Francisco, CA 94133-3908   Seafood, Vegetarian Friendly, Vegan Options
# 1     Hackensack, NJ 07601-6337          Diner, American, Vegetarian Friendly
# 2   Poughkeepsie, NY 12601-5476          American, Diner, Vegetarian Friendly
# 3          Plano, TX 75093-7777       American, Wine Bar, Vegetarian Friendly
# 4            Syracuse, NY 13212                        American, Bar, Seafood
#
#             Reviews No of Reviews  \
# 0  4.5 of 5 bubbles   243 reviews
# 1    4 of 5 bubbles    84 reviews
# 2    4 of 5 bubbles   256 reviews
# 3  4.5 of 5 bubbles   235 reviews
# 4    4 of 5 bubbles   285 reviews
#
#                                             Comments Price_Range
# 0                                                NaN    $$ - $$$
# 1  Both times we were there very late, after 11 P...    $$ - $$$
# 2  Waitress was very friendly but a little pricey...    $$ - $$$
# 3  Not sure why I went there for the second time....    $$ - $$$
# 4  Doesn't look like much from the outside but wa...    $$ - $$$

# %%
# Cek Data Modus
df.describe(include=['object'])
# Out:
#                    Name   Street Address                   Location  \
# count              3062             3062                       3062
# unique             2641             2814                       2653
# top     Texas Roadhouse  3333 Bristol St  Costa Mesa, CA 92626-1873
# freq                 13                8                          8
#
#                                                 Type           Reviews  \
# count                                           3049              3062
# unique                                           669                 6
# top      Italian, Vegetarian Friendly, Vegan Options  4.5 of 5 bubbles
# freq                                             137              1956
#
#        No of Reviews                                           Comments  \
# count           3062                                               2447
# unique           811                                               2291
# top       58 reviews  The most warn and welcoming environment, Excel...
# freq              18                                                  4
#
#        Price_Range
# count         3062
# unique           6
# top       $$ - $$$
# freq          2385

# %% [markdown]
# Penjelasan
# - Texas Roadhouse memiliki 13 kali penyebutan dalam reviews/comment

# %% [markdown]
# ---

# %% [markdown]
#  # ii. Data Cleaning

# %%
df.isnull().sum()
# Out:
# Name                0
# Street Address      0
# Location            0
# Type               13
# Reviews             0
# No of Reviews       0
# Comments          615
# Price_Range         0
# dtype: int64

# %%
# cek comment
df[df['Comments'].isnull()].head()
# Out:
#                              Name      Street Address  \
# 0   Betty Lou's Seafood and Grill    318 Columbus Ave
# 5                     E Tutto Qua    270 Columbus Ave
# 16                         Malbec     1001 E Green St
# 19                    Mimi's Cafe  1400 S Harbor Blvd
# 23               The Lion's Share    629 Kettner Blvd
#
#                         Location  \
# 0   San Francisco, CA 94133-3908
# 5   San Francisco, CA 94133-4518
# 16       Pasadena, CA 91106-2404
# 19        Anaheim, CA 92802-2311
# 23      San Diego, CA 92101-6718
#
#                                               Type           Reviews  \
# 0      Seafood, Vegetarian Friendly, Vegan Options  4.5 of 5 bubbles
# 5                          Seafood, Italian, Pizza  4.5 of 5 bubbles
# 16                  Steakhouse, Latin, Argentinean  4.5 of 5 bubbles
# 19   American, Cajun & Creole, Vegetarian Friendly    4 of 5 bubbles
# 23              American, Bar, Gluten Free Options  4.5 of 5 bubbles
#
#     No of Reviews Comments Price_Range
# 0     243 reviews      NaN    $$ - $$$
# 5   1,406 reviews      NaN    $$ - $$$
# 16    193 reviews      NaN        $$$$
# 19  1,807 reviews      NaN    $$ - $$$
# 23    179 reviews      NaN    $$ - $$$

# %%
# cek type
df[df['Type'].isnull()].head()
# Out:
#                                    Name        Street Address  \
# 49      Luby's Cafeteria Mall Del Norte            5300 Ih 35
# 267                          Very Juice          422 Avenue P
# 1000               Cast Iron Trading Co  114 N San Joaquin St
# 1238  Sir Winston's Restaurant & Lounge       1126 Queens Hwy
# 1629   Benji's French Basque Restaurant     4001 Rosedale Hwy
#
#                         Location Type           Reviews No of Reviews  \
# 49                    Laredo, TX  NaN    4 of 5 bubbles    27 reviews
# 267      Brooklyn, NY 11223-1935  NaN    5 of 5 bubbles      1 review
# 1000     Stockton, CA 95202-2407  NaN  4.5 of 5 bubbles    11 reviews
# 1238   Long Beach, CA 90802-6331  NaN  4.5 of 5 bubbles   490 reviews
# 1629  Bakersfield, CA 93308-6130  NaN    4 of 5 bubbles   157 reviews
#
#                                                Comments    Price_Range
# 49    Located inside the Mall Del Norte, this is a r...       American
# 267   I travel a lot but couldn’t find better Peanut...  Not Specified
# 1000                                                NaN  Not Specified
# 1238                                                NaN           $$$$
# 1629                                                NaN       $$ - $$$

# %%
# Cek data Reviews dan No of reviews
print(df.Reviews.unique())
display(df[df.Reviews=='No review'])

display(df[df['No of Reviews']=='Undefined Number'])
# Out:
# ['4.5 of 5 bubbles' '4 of 5 bubbles' '5 of 5 bubbles' '3.5 of 5 bubbles'
#  '3 of 5 bubbles' 'No review']
#                   Name Street Address                   Location Type  \
# 1744  Wavershak's Deli   1800 Route 9  Toms River, NJ 08755-1284  NaN
# 2866  Wavershak's Deli   1800 Route 9  Toms River, NJ 08755-1284  NaN
#
#         Reviews     No of Reviews     Comments    Price_Range
# 1744  No review  Undefined Number  No Comments  Not Specified
# 2866  No review  Undefined Number  No Comments  Not Specified
#                   Name Street Address                   Location Type  \
# 1744  Wavershak's Deli   1800 Route 9  Toms River, NJ 08755-1284  NaN
# 2866  Wavershak's Deli   1800 Route 9  Toms River, NJ 08755-1284  NaN
#
#         Reviews     No of Reviews     Comments    Price_Range
# 1744  No review  Undefined Number  No Comments  Not Specified
# 2866  No review  Undefined Number  No Comments  Not Specified

# %%
### Drop Rows which are not required and reset index
df = df.drop([1744,2866])
df = df.reset_index(drop=True)

# %%
# Kompilasi membersihkan data secara umum

def clean_data(df):

  price_range_map = {'$': 1, '$$ - $$$': 2, '$$$$': 3}
  df['Price_Range'] = df['Price_Range'].map(price_range_map)

  df['Reviews'] = [float(i.split(" ")[0]) for i in df.Reviews]
  df['No of Reviews'] = [int(i.split(" ")[0].replace(",","")) for i in df['No of Reviews']]

  df[['Type1', 'Type2', 'Type3']] = df['Type'].str.split(',', expand=True).apply(lambda x: x.str.strip())

  df[['city', 'state_zip']] = df['Location'].str.rsplit(', ', n=1, expand=True)
  df[['State', 'zip']] = df['state_zip'].str.rsplit(' ', n=1, expand=True)

  df = df[df['State'] != ''].copy()

  df = df.drop('Location', axis=1)
  df = df.drop('zip', axis=1)
  df = df.drop('state_zip', axis=1)
  df.drop_duplicates(inplace=True)

  df.dropna(inplace=True)

  # rename kolom jadi huruf kecil
  df.columns = df.columns.str.lower()
  df.columns = df.columns.str.replace(' ', '_')

  return df

# %%
df_clean = clean_data(df)

# %%
df_clean['state'].unique()
# Out:
# array(['NJ', 'NY', 'TX', 'WA', 'OR', 'PA'], dtype=object)

# %%
df_clean['description'] = df_clean['type'] + ' ' + df_clean['comments']

# %%
df_clean.shape
# Out:
# (1939, 13)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1939 entries, 1 to 3059
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1939 non-null   object
#  1   street_address  1939 non-null   object
#  2   type            1939 non-null   object
#  3   reviews         1939 non-null   float64
#  4   no_of_reviews   1939 non-null   int64
#  5   comments        1939 non-null   object
#  6   price_range     1939 non-null   float64
#  7   type1           1939 non-null   object
#  8   type2           1939 non-null   object
#  9   type3           1939 non-null   object
#  10  city            1939 non-null   object
#  11  state           1939 non-null   object
#  12  description     1939 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 212.1+ KB

# %% [markdown]
# Jadi hasil yang kita dapat 1939 restoran

# %%
for col in df_clean.columns:
    if df_clean[col].dtype == 'object':
        df_clean[col] = df_clean[col].str.lower()

# %%
df_clean.head()
# Out:
#                                    name       street_address  \
# 1                     coach house diner        55 state rt 4
# 2                      table talk diner  2521 south rd ste c
# 3                           sixty vines     3701 dallas pkwy
# 4                          the clam bar    3914 brewerton rd
# 6  black angus steakhouse - federal way      2400 s 320th st
#
#                                        type  reviews  no_of_reviews  \
# 1      diner, american, vegetarian friendly      4.0             84
# 2      american, diner, vegetarian friendly      4.0            256
# 3   american, wine bar, vegetarian friendly      4.5            235
# 4                    american, bar, seafood      4.0            285
# 6                 american, steakhouse, bar      4.0            220
#
#                                             comments  price_range     type1  \
# 1  both times we were there very late, after 11 p...          2.0     diner
# 2  waitress was very friendly but a little pricey...          2.0  american
# 3  not sure why i went there for the second time....          2.0  american
# 4  doesn't look like much from the outside but wa...          2.0  american
# 6  this is an easy any time place to have dinner!...          2.0  american
#
#         type2                type3          city state  \
# 1    american  vegetarian friendly    hackensack    nj
# 2       diner  vegetarian friendly  poughkeepsie    ny
# 3    wine bar  vegetarian friendly         plano    tx
# 4         bar              seafood      syracuse    ny
# 6  steakhouse                  bar   federal way    wa
#
#                                          description
# 1   diner, american, vegetarian friendly both tim...
# 2   american, diner, vegetarian friendly waitress...
# 3   american, wine bar, vegetarian friendly not s...
# 4   american, bar, seafood doesn't look like much...
# 6   american, steakhouse, bar this is an easy any...

# %% [markdown]
# ---

# %% [markdown]
# # iv. Exploratory Data Analysis (EDA)

# %% [markdown]
# **A. Top makanan terpopuler berdasarkan type**

# %%
corpus = " ".join(df_clean['type1'])
word_cloud = WordCloud(max_words=100, background_color='white', min_font_size=10).generate(corpus)

# Convert the word cloud to an image
img = word_cloud.to_image()

# Plot the word cloud
fig = plt.figure(1)
plt.title('Top Type Culture Masakan di Type1')
plt.imshow(img, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Buat dataframe
pd.DataFrame({'Jumlah Restoran yang Melayani':df_clean['type1'].value_counts()}).head(10)
# Out:
#                Jumlah Restoran yang Melayani
# type1
# american                                 867
# italian                                  325
# mexican                                  131
# asian                                     84
# mediterranean                             64
# japanese                                  53
# seafood                                   43
# chinese                                   36
# indian                                    33
# pizza                                     31

# %%
corpus = " ".join(df_clean['type2'])
word_cloud = WordCloud(max_words=100, background_color='white', min_font_size=10).generate(corpus)

# Convert the word cloud to an image
img = word_cloud.to_image()

# Plot the word cloud
fig = plt.figure(1)
plt.title('Top Type Culture Masakan di Type2')
plt.imshow(img, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Buat dataframe
pd.DataFrame({'Jumlah Restoran yang Melayani':df_clean['type2'].value_counts()}).head(10)
# Out:
#                      Jumlah Restoran yang Melayani
# type2
# bar                                            310
# vegetarian friendly                            307
# pizza                                          126
# steakhouse                                     108
# seafood                                        104
# american                                        93
# southwestern                                    85
# cafe                                            77
# latin                                           58
# diner                                           57

# %%
corpus = " ".join(df_clean['type3'])
word_cloud = WordCloud(max_words=100, background_color='white', min_font_size=10).generate(corpus)

# Convert the word cloud to an image
img = word_cloud.to_image()

# Plot the word cloud
fig = plt.figure(1)
plt.title('Top Type Culture Masakan di Type3')
plt.imshow(img, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Buat dataframe
pd.DataFrame({'Jumlah Restoran yang Melayani':df_clean['type3'].value_counts()}).head(10)
# Out:
#                      Jumlah Restoran yang Melayani
# type3
# vegetarian friendly                            707
# vegan options                                  255
# gluten free options                            184
# pub                                            124
# bar                                             62
# seafood                                         62
# asian                                           54
# spanish                                         36
# latin                                           31
# american                                        28

# %% [markdown]
# Penjelasan:
# - Berdasarkan hasil bahwa top makanan yang memiliki frequency tinggi adalah `American`, `bar` dan `Vegetarian Friendly`

# %% [markdown]
# **B. Negara bagian ('State') mana yang memiliki Jumlah Restoran Terbanyak?**

# %%
ax = df_clean['state'].value_counts().plot(kind="bar", color="Blue",  figsize=(10,5))

ax.set_ylabel('Jumlah Restoran')
ax.set_xlabel('State')
plot = ax.set_title("Jumlah Restoran per Negara Bagian")

# %%
pd.DataFrame({'Jumlah Restoran per Negara Bagian':df_clean['state'].value_counts()}).head(10)
# Out:
#        Jumlah Restoran per Negara Bagian
# state
# wa                                   505
# ny                                   496
# tx                                   493
# nj                                   434
# pa                                     9
# or                                     2

# %% [markdown]
# Jumlah Restoran Terbanyak berada di WA diikuti oleh New york

# %% [markdown]
# **C. Peringkat restoran terbaik (memberi rating tinggi) dari setiap negara bagian**

# %% [markdown]
# Restoran dengan rating tinggi memiliki asumsi 2 faktor:
# - Jumlah orang yang me-reviews
# - Membering rating tinggi 5

# %%
# Menghitung bobot Rating
df_clean['weighted_ratings'] = df_clean['reviews']*df_clean['no_of_reviews']
df_clean['weighted_ratings']
# Out:
# 1        336.0
# 2       1024.0
# 3       1057.5
# 4       1140.0
# 6        880.0
#          ...
# 3053    1692.0
# 3055     891.0
# 3057     844.0
# 3058     348.0
# 3059     823.5
# Name: weighted_ratings, Length: 1939, dtype: float64

# %%
labels = df_clean.state.unique().flatten()
average_vote_share_list = [df_clean[df_clean.state==i].weighted_ratings.max() for i in labels]
avg_wt_ratings = pd.DataFrame({'state':labels, 'Weighted Average Ratings': average_vote_share_list})
plot = sns.catplot(x='state', y="Weighted Average Ratings", kind="bar", data=avg_wt_ratings, palette="rocket")
plt.title("Best Restaurant among all states")
plt.gcf().set_size_inches(9, 6)

# %%
df_clean[df_clean.weighted_ratings==df_clean.weighted_ratings.max()]
# Out:
#                        name        street_address  \
# 2164  big texan steak ranch  7701 e interstate 40
#
#                                      type  reviews  no_of_reviews  \
# 2164   american, steakhouse, southwestern      4.0           5448
#
#                                                comments  price_range  \
# 2164  roquefort dressing homemade and delicious. i h...          2.0
#
#          type1       type2         type3      city state  \
# 2164  american  steakhouse  southwestern  amarillo    tx
#
#                                             description  weighted_ratings
# 2164   american, steakhouse, southwestern roquefort ...           21792.0

# %% [markdown]
# `Big Texan Steak Ranch` di Texas dipandang sebagai yang terbaik di antara semua negara bagian. Kita ingin memahami alasannya. Sebagaimana kita telah diskusikan sebelumnya, tidak ada yang mempengaruhi kesuksesan restoran seperti peringkat dari para pengulas.

# %%
df_clean[df_clean['no_of_reviews'] == df_clean['no_of_reviews'].max()]
# Out:
#                        name        street_address  \
# 2164  big texan steak ranch  7701 e interstate 40
#
#                                      type  reviews  no_of_reviews  \
# 2164   american, steakhouse, southwestern      4.0           5448
#
#                                                comments  price_range  \
# 2164  roquefort dressing homemade and delicious. i h...          2.0
#
#          type1       type2         type3      city state  \
# 2164  american  steakhouse  southwestern  amarillo    tx
#
#                                             description  weighted_ratings
# 2164   american, steakhouse, southwestern roquefort ...           21792.0

# %% [markdown]
# `Big Texan Steak Ranch` memang menjadi sorotan karena minimnya ulasan yang diberikan, yang pada akhirnya menghasilkan peringkat rata-rata yang tinggi, sekitar 4,0. Kondisi ini menjadikannya restoran yang paling diunggulkan di seluruh negara bagian.

# %% [markdown]
# **D. Negara Bagian ('state') Terbaik untuk Makanan?**
#
# Berdasarkan bobot ratings
# 'Weighted Ratings - No of Reviewers * Average Ratings'
#
# - Artinya 500 orang yang memberi rata-rata rating 4,0 jauh lebih berpengaruh dibandingkan 200 orang yang memberi rata-rata rating 4,5
#
# - Faktor lain yang mempengaruhi adalah jumlah restoran. Setiap Restoran akan memiliki kumpulan pengulas dan penilaiannya sendiri.
#
# - Oleh karena itu, untuk mendapatkan gambaran keseluruhan yang baik, menambahkan semua peringkat tertimbang menurut negara bagian dan membandingkannya masih merupakan gambaran yang lebih baik

# %%
labels = df_clean.state.unique().flatten()
total_vote_share_list = [df_clean[df_clean.state==i].weighted_ratings.sum() for i in labels]
total_wt_ratings = pd.DataFrame({'state':labels, 'Total Weighted Ratings': total_vote_share_list})
plot = sns.catplot(x='state', y="Total Weighted Ratings", kind="bar", data=total_wt_ratings, palette="husl")
plt.title("Best state For Food")
plt.gcf().set_size_inches(9, 6)

# %% [markdown]
# Dari hasil kita dapatkan dengan mempertimbangkan Weighted Ratings dan jumlah restoran, kami menjadikan New York sebagai negara bagian terbaik secara keseluruhan untuk makanan, diikuti Texas.

# %% [markdown]
# **E. Kota Terbaik untuk Makanan?**

# %%
labels = df_clean.city.unique().flatten()
total_vote_share_list = [df_clean[df_clean.city==i].weighted_ratings.sum() for i in labels]
total_wt_ratings = pd.DataFrame({'city':labels, 'Total Weighted Ratings': total_vote_share_list})
total_wt_ratings = total_wt_ratings.sort_values(by=['Total Weighted Ratings'],ascending=False).head(5)
plot = sns.catplot(x='city', y="Total Weighted Ratings", kind="bar", data=total_wt_ratings, palette="cubehelix")
plt.title("Top 5 Cities For Food")
plt.gcf().set_size_inches(9, 6)

# %% [markdown]
# Kota New York sejauh ini merupakan kota terbaik untuk makanan berdasarkan Weighted Ratings

# %% [markdown]
# **F. Distribusi Price Range**

# %%
# Menghitung jumlah setiap kategori dalam kolom 'price_range'
price_range_counts = df_clean['price_range'].value_counts()
print(price_range_counts)

labels = {1.0:'low budget', 2.0:'Mid budget', 3.0:'high budget'}

# Membuat pie chart
plt.figure(figsize=(8, 8))
plt.pie(price_range_counts, labels=price_range_counts.index.map(labels), autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Price Range')
plt.show()
# Out:
# price_range
# 2.0    1535
# 3.0     248
# 1.0     156
# Name: count, dtype: int64

# %% [markdown]
# Dari hasil di dapat bahwa budget medium adalah yang mendominasi dataset ini

# %% [markdown]
# ---

# %%
df_clean.head()
# Out:
#                                    name       street_address  \
# 1                     coach house diner        55 state rt 4
# 2                      table talk diner  2521 south rd ste c
# 3                           sixty vines     3701 dallas pkwy
# 4                          the clam bar    3914 brewerton rd
# 6  black angus steakhouse - federal way      2400 s 320th st
#
#                                        type  reviews  no_of_reviews  \
# 1      diner, american, vegetarian friendly      4.0             84
# 2      american, diner, vegetarian friendly      4.0            256
# 3   american, wine bar, vegetarian friendly      4.5            235
# 4                    american, bar, seafood      4.0            285
# 6                 american, steakhouse, bar      4.0            220
#
#                                             comments  price_range     type1  \
# 1  both times we were there very late, after 11 p...          2.0     diner
# 2  waitress was very friendly but a little pricey...          2.0  american
# 3  not sure why i went there for the second time....          2.0  american
# 4  doesn't look like much from the outside but wa...          2.0  american
# 6  this is an easy any time place to have dinner!...          2.0  american
#
#         type2                type3          city state  \
# 1    american  vegetarian friendly    hackensack    nj
# 2       diner  vegetarian friendly  poughkeepsie    ny
# 3    wine bar  vegetarian friendly         plano    tx
# 4         bar              seafood      syracuse    ny
# 6  steakhouse                  bar   federal way    wa
#
#                                          description  weighted_ratings
# 1   diner, american, vegetarian friendly both tim...             336.0
# 2   american, diner, vegetarian friendly waitress...            1024.0
# 3   american, wine bar, vegetarian friendly not s...            1057.5
# 4   american, bar, seafood doesn't look like much...            1140.0
# 6   american, steakhouse, bar this is an easy any...             880.0

# %% [markdown]
# # Feature Enginering
#
# Tujuan kita adalah membuat sistem rekomendasi berdasarkan Content-base-filtering, target kita adalah nama restoran dan feature adalah description dimana dari hasil comments + type

# %%
pprint(df_clean['description'].to_list())
# Out:
# [' diner, american, vegetarian friendly both times we were there very late, '
#  'after 11 pm.  at that time in many diners (forget restaurants!) you get '
#  'warmed-over food and lousy service.  not so here - food was uniformly very '
#  "good and the service quite good.  there weren't many people but it...more",
#  ' american, diner, vegetarian friendly waitress was very friendly but a '
#  'little pricey for a diner but the food was delicious \n'
#  'the menu had a wide variety of foods to choose from but any choice would '
#  'have been a good one',
#  ' american, wine bar, vegetarian friendly not sure why i went there for the '
#  'second time. will not go again. not because it was terrible but because it '
#  'is just average.  \n'
#  'the place needs a food clean .... our menus were filthy...the table was '
#  'filthy \n'
#  'it is impossible to have a...more',
#  " american, bar, seafood doesn't look like much from the outside but walk in "
#  'either the front door or back door and get greeted and sat almost '
#  'immediately. waitress was amazing and very helpful with the very large '
#  'variety that they offer. my wife and i were very satisfied...more',
#  ' american, steakhouse, bar this is an easy any time place to have dinner!  '
#  'from week night to a special occasion.  the food is reasonably priced and '
#  'always delicious!',
#  ' mediterranean, greek, healthy my husband and i went to greece last fall and '
#  'fell in love with the beauty and the food so while on a  dallas business '
#  "trip, we came across ziziki's and thought we'd give it a go knowing that "
#  'this was risky after 2 weeks...more',
#  " italian, pizza, vegetarian friendly i love vince's pizza and i was in the "
#  'neighborhood after a meeting. i had a small pizza and salad.  both were '
#  'delicious and as i would expect. the service was friendly and attentive. the '
#  'delivery was as quick as one can expect for a...more',
#  ' american, steakhouse, gluten free options the ambience, food and service '
#  'were all excellent. with a student at cornell we look forward to more '
#  'dinners there!',
#  ' italian, vegetarian friendly, gluten free options nice big dining area.  '
#  'holds many people, so never feels crowded.  food and cocktails are really '
#  'good.',
#  " cafe, american, vegetarian friendly this is the place if you're into the "
#  "combo of excellent and sincerely unpretentious.  i'm not usually a breakfast "
#  "lover - but i'll be back here to try their corned beef on potatoes and a few "
#  'other treats.',
#  ' irish, bar, pub have been here before. this time it was disappointing. beer '
#  'variety and selection as always good but food wasn´t worth the price-\n'
#  'fish and meet portion in general small and all close to well-done.\n'
#  'service personal wasn´t committed. once we finished the dinner plates '
#  'were...more',
#  ' american, bar, vegetarian friendly came with a group of eight people, and '
#  'had a wonderful evening.  the food was a wide variety, and very high '
#  'quality.  service was excellent.  the flatbread deluxe hamburger was a '
#  'unique burger, and extremely tasty.  the spicy grilled green bean appetizer '
#  'platter was outstanding....more',
#  ' american, cafe, healthy my first time in this part of montclair. since i '
#  'arrived at 12.15 pm, there was never ending influx of customers for a good 2 '
#  'hours.  as busy as this restaurant is, we were not rushed and we fully '
#  'enjoyed our food while enjoying our...more',
#  ' american, bar, pub we brought our family here for dinner on a saturday. it '
#  'was busy but the staff was very attentive and our food did not take too '
#  'long. the tiger tots were amazing!  the rest of our food was good as well. a '
#  'little noisy and...more',
#  ' chinese, asian, taiwanese din tai fung has always been inconstantly great.  '
#  'the dumplings, noodles, and rice dishes are sublime and the service is fast '
#  'and friendly. \n'
#  '\n'
#  'while everything is great and fresh ]make sure you do not forget your '
#  'vegetables as the greens here are a work of...more',
#  ' belgian, french, cafe the food and service were very good, but the size of '
#  'the portions relative to price were a little disappointing.  they did nicely '
#  'accommodate our large family gathering, which was nice!  the poutine was '
#  'outstanding!more',
#  ' steakhouse, mexican, vegetarian friendly food always great and the '
#  'margaritas are the best. wait staff are always courteous and friendly. best '
#  'texmex in town.',
#  ' american, vegetarian friendly, vegan options we dined for lunch (group of '
#  'four) and all ordered the 3-course offering for $18.99\n'
#  'excellent value and the quality was exceptional. food was fresh,\n'
#  ' hot and adequately portioned.no disappointment.\n'
#  '\n'
#  'better than the food(which is hard to do)was our attentive pleasant server '
#  'eden. she truly...more',
#  ' bar, contemporary, fusion took my fiancé here for valentine’s day. she '
#  'discovered a while back that she has a gluten allergy which has really '
#  'limited what she can eat. i on the other hand, was very skeptical. long '
#  'story short, the food was delicious and i left very...more',
#  ' american, european, vegetarian friendly one of our favorite brunch place in '
#  'seattle. came back for the second time while we were in town. food is '
#  'absolutely lovely but the baked potatoes were a bit too dry for my taste. '
#  'overall, great place for brunch.',
#  ' italian, vegetarian friendly, gluten free options bv tuscany is in a great '
#  'location with shops and a local movie theater. we always find street parking '
#  'close by. the food is delicious so fresh, excellent quality. the service is '
#  'always on point so friendly too! its very romantic inside. the desserts '
#  'are...more',
#  ' latin, spanish, vegetarian friendly this place is horrible!!!!!  they dont '
#  'know how to treat customers especially when they are at fault.  this place '
#  'is ran by idiots and the owner should be ashamed of who he has representing '
#  'him. i was a loyal customer for 4 years and after...more',
#  ' american, bar, gastropub went recently on a saturday night for a birthday '
#  "celebration. we do like the atmosphere. it's loud but we didn't mind. the "
#  'menu is very eclectic and appealing. problem is most everything just left '
#  'the little bit to be desired. mainly not enough in the...more',
#  ' italian, vegetarian friendly, gluten free options we live part time in '
#  'italy and are tough critics of many italian restaurants in the us.  paradise '
#  'surprised us with two excellent dishes that would have been very good in '
#  'italy.  the pasta with cream sauce and sausage was super.  very rich and '
#  'creamy...more',
#  ' spanish, mediterranean, wine bar unique tapas menu - not a mexican '
#  'restaurant! my waiter made excellent recommendations and of course, the '
#  'small portions or “tapas”, made it ideal to try several. \n'
#  '\n'
#  'everything i ordered was de-lish!\n'
#  '\n'
#  'classy, relaxing ambiance.',
#  " chinese, asian, vegetarian friendly i can't tell you enough of how amazing "
#  'the food here is. the edamam ravioli are to die for. there is not one dish i '
#  "didn't like. this is my favorite part of visiting atlantic city",
#  ' mexican, southwestern, vegetarian friendly decent service.  nothing to '
#  'write home about.  got the fajitas and the meat was way over seasoned and '
#  'the beef was super chewy. the tortillas were the only good thing of that '
#  'meal.  my sister got the stuffed avocado meal and was not good.  it...more',
#  ' mediterranean, greek, italian great staff, super atmosphere and superb '
#  'staff! if you like greek food, this place is a must!  compared to the other '
#  'restaurants at the star, it is actually not overcrowded.  well worth a '
#  'visit!',
#  ' italian, vegetarian friendly, vegan options fabulous!  deserves the '
#  'michelin star that it already has.  we had the 5 course dinner on a wintry '
#  'sunday night.  all 5 courses were marvelous!  having said that, the linguine '
#  'with geoduck was my favorite, followed closely by the veal/tuna/sweetbread '
#  'appetizer.  pork agnolotti and branzino...more',
#  " american, bar, pub on tuesdays moore's has 2 for 1 burgers. the burgers are "
#  'good and large. the service however was not so good. my wife ordered bacon '
#  'with her burger but did not get it. when we mentioned this to the waitress '
#  "so we wouldn't be charged...more",
#  ' american, steakhouse, gluten free options such a nice evening! professional '
#  'and kind service in a cozy atmosphere. everything was delicious. we shared '
#  'oysters, truffle fries and asparagus. we both had beautiful steaks. would go '
#  'monthly if i lived here.',
#  ' italian, pizza, vegetarian friendly six of us dined here last night - '
#  'carbonara, pizzas, gnocchi, caprese and desserts were all excellent - both '
#  'taste and presentation.  warm, friendly and attentive service. love this '
#  'place!  a new favorite in seattle.',
#  ' caribbean, latin, spanish we came with high hopes and left underwhelmed. we '
#  'were hoping for something a bit different, and interesting. the waitress '
#  'spent more time describing drinks than food, which made me realise that this '
#  'was more of a bar than a restaurant. and the food was...more',
#  ' american, cafe, diner great home style food. yummy breakfast. large '
#  'portions. have tried chicken strips, burgers, chicken fried steak and pies. '
#  'all great!',
#  ' american, southwestern, vegetarian friendly what a fantastic experience. '
#  'the bartender was very knowledgeable about the menu and a joy to talk with.  '
#  'our server joe as knowledgeable and attentive. the food was devine.  the '
#  'appetizers were out of this world.  i had the elk for my main course '
#  'and...more',
#  ' indian, asian, vegetarian friendly we thoroughly enjoyed our valentine’s '
#  'weekend dinner here!  we’d been advised by a friend to arrive early on a '
#  'weekend, so we arrived as they opened for the dinner service @ 5:30 (they '
#  'don’t accept weekend reservations).  by 6:00 pm there was a line of...more',
#  ' american, bar, international if you are in frisco you have to stop here. '
#  'the drinks are amazing. service is great. food is great.',
#  ' american, bar, seafood we sure enjoyed our meal and the margaritas we had '
#  'at buzzard billy’s. the place was hard to get to because of construction but '
#  'well worth it. it’s on the river and has a great view and was very nice '
#  'indoors with friendly staff.',
#  ' american, seafood, vegetarian friendly the 3 course menu for $25 is '
#  'available anytime in january which is a good deal. the salmon dip and '
#  'northwest duet were good. however the salmon dip was only accompanied by a '
#  'couple of crackers and slices of apple. the hot fudge sundae for...more',
#  ' asian, thai, vegetarian friendly we had a meeting in federal way that was '
#  'going to end late, and i knew we needed to get to lunch right away, so i '
#  'researched places. this sounded good, and am i glad we went!  we had the '
#  'kwan tip wings, which was...more',
#  ' greek, italian, pizza this place has been run by the same family since they '
#  'opened in 1973.  i had a salad and a half meatball grinder, sliced meatballs '
#  'with tomato sauce and cheese.  these things are delicious but can be messy '
#  'to eat.  imagine if it had round...more',
#  ' american, seafood, bar we were excited to go here and have an early '
#  "valentine's day dinner, thursday, the day before the holiday and see if "
#  'things had changed with the new owner. we sat in the lounge while we waited '
#  'for our table. the atmosphere was relaxed, the...more',
#  ' american, seafood, gluten free options three star restaurant, open all year '
#  'byob.classy, elegant dining. wine glasses, table cloths. there’s not one '
#  'thing on the fine menu that i would not try! great chef! you got me '
#  'hooked!!!🤙🤙🤙',
#  ' american, steakhouse, vegetarian friendly service was great and the steaks '
#  'were awesome. i highly recommend this capital grill when in nyc. everyone '
#  'was accomodating.',
#  ' american, bar, seafood they nailed the cajun atmosphere, felt like we could '
#  'be dining in a new orleans restaurant! our waitress was very bubbly, '
#  'attentive and informative. we ordered oysters from 3 different north eastern '
#  'states. i had only had oysters from the gulf and never knew they...more',
#  ' american, vegetarian friendly, vegan options lots of bread and butter to '
#  'start.\n'
#  'expensive, small drinks with too much ice no matter what you ask for.\n'
#  'big bowls of cheap lettuce with minimal nothing special ingredients.\n'
#  'and - $9 a slice for their 2,000 calorie cheesecake lol. argh! \n'
#  'stay away please...more',
#  ' american, steakhouse, gluten free options tremendous service.  nice '
#  'atmosphere.  ordered the large filet mignon and it had a lot of grisly fat '
#  "in the middle.  didn't complain cause im not one for that, but that is a few "
#  'times now where my steak there was well below average.  i prefer...more',
#  ' american, vegetarian friendly, vegan options we ordered from this '
#  'location \n'
#  "and i'll say excellent burgers.  \n"
#  'good size..  very tasty\n'
#  'but very pricey',
#  ' japanese, sushi, asian we had the mt st helens special.  it’s a roll with '
#  'avocado and crab meat inside and a fish variety on the outside.  it was '
#  'great and creative.  the sushi we had was all very good.  \n'
#  '\n'
#  'the soba noodle was mediocre, so don’t go for...more',
#  ' asian, thai, vegetarian friendly recently received a score of 60 from '
#  'health department.  a score of 100 or higher  is closing the establishment \n'
#  "don't think i'll be back.",
#  ' thai, asian, vegan options an extensive menu that does not disappoint. this '
#  'is my go-to place for thai food near home. i love both the tom yum and the '
#  'tom ka soups. i often just order the soup with a side of rice for an '
#  'excellent meal.',
#  ' italian, american, pizza even a boy from brooklyn ny enjoyed the pizza. '
#  'nice soft pizza with good cheese, mushrooms and pepperoni. also had a bison '
#  'burger which was cooked the way we like it. \n'
#  '\n'
#  'and the staff was extremely helpful and attentive. we carried out and '
#  'everything was...more',
#  ' american, southwestern, bar had a valentine dinner with my wife. she had '
#  'the grilled ruby red trout and she said it was excellent. i had the crispy '
#  'fried red fish and it was excellent. our waiter was very personable and '
#  'excellent service.',
#  ' italian, american, seafood what can i say ? when in austin you should visit '
#  'la volpe, my first time around and by far i am already in love. i had no '
#  'idea about the restaurant but my mom is from around and she told me about '
#  'this incredible...more',
#  ' asian, indian, tibetan our group of 4 was limited in knowledge of the '
#  'restaruant fare.  our server, anis, was very helpful in suggesting items '
#  'that made our dining experience very enjoyable.  we enjoyed panner momos, '
#  'spinach naan, vegetable thukpa, mango chicken, and lamb saag.  with our '
#  'restaurant.com coupon,...more',
#  ' american, steakhouse, southwestern my first time visiting this restaurant. '
#  'oh my!! it was phenomenal from walking in the doors to walking out with a '
#  'full stomach! service, food, atmosphere, prices... i was not disappointed by '
#  'any means.',
#  ' american, wine bar, vegetarian friendly the food was very very good.\n'
#  'over priced in my opinion, but extremely good. not a big selection to choose '
#  'from.\n'
#  'the waitress was extremely good in the beginning but tended to ignore us at '
#  'the end. \n'
#  'the place was so crowded people were standing...more',
#  ' latin, cuban, caribbean visted on a sat night...busy so make sure you '
#  'reserve a table...moderately priced....excellent portions...started with 3 '
#  'beef empanadas....tasty and not greasy at all....also had the cuban '
#  'chorizo..could have been spicier..but it was excellent...for entrees stuffed '
#  'porkchop with chorizo and manchego cheese....smothered in pears and '
#  'onions...also...more',
#  ' italian, pizza, vegetarian friendly we heard about pane e vino from a '
#  'friend and decided to try it.  we were met by the owner and escorted to our '
#  'table.  three of us ordered the lasagna and thought it was really good.  the '
#  'fourth person ordered the veal picatta and...more',
#  ' american, vegetarian friendly, gluten free options my sister and i came '
#  'here on christmas eve for dinner and it could not have been more pleasant!!  '
#  'we both had melt in your mouth salmon, which was expertly prepared and we '
#  'both loved!!  also had a delightful cheesecake with wonderful coffee for '
#  'dessert,...more',
#  ' american, seafood, gluten free options this restaurant feels like you are '
#  'walking into the past in a good way. greeted by a gentleman who was polite '
#  'and very organized. our waiter never stopped moving was very polite. he was '
#  'good about all of our requests. we even had to make...more',
#  ' indonesian, american, vegetarian friendly we’ve been in this nice and '
#  'classy place for dinner with my husband and we remain very satisfied of our '
#  'four corses menu! every plate was delicious and service was awesome) the '
#  'chief was attentive to every guest! recommended!',
#  ' american, steakhouse, gluten free options celebrating the end of 2019.  '
#  'reserved for 2 at 4:45, yet table set for four...awkward.  lots of young '
#  'families with small children. fun to watch!  my gorgeous smart & sweet wife '
#  'had the modern caesar salad that comes with two pieces of petite garlic '
#  'toasts....more',
#  ' italian, vegetarian friendly, vegan options my sisters and their husbands '
#  'and i went here for my mom’s 88th birthday. wonderful restaurant. the food '
#  'and service were spectacular. the portions were surprisingly large. but of '
#  'course you pay for what you get. my brother-in-law picked up the tab, which '
#  'had to...more',
#  ' italian, pizza, fast food black friday everything else was very crowded so '
#  'we decided to grab a quick bite here. the line moved fast so was good. the '
#  'cheese pizza was good. but the veggie was below average.the spaghetti was '
#  'okay',
#  ' latin, barbecue, brazilian food and drinks are always on point. i visit 3 '
#  'to 4 times a month. today they had a guest singer. just aweful!! he cannot '
#  'sings,sounds terrible and just loud. how do you chase customers away? have '
#  'the band that played at brasilia on feb...more',
#  ' american, bar, pub we stopped in as it looked so cozy with real wood '
#  'burning fireplaces . the menu had some unique items and many beers to choose '
#  'from. our waiter dave suggested the beer and was exactly what my husband '
#  'liked. then he asked me what i...more',
#  ' american, sushi, gluten free options metropolitan cafe is dependable, '
#  'always has fresh delicious food. we went most recently for a brunch and it '
#  'was delicious. a large variety of options, great bar,  and they take '
#  'reservations-which isn’t common for brunch in the area.',
#  ' american, barbecue, gluten free options we went here because it was walking '
#  'distance to the hotel. everything is a la carte. we both had the "dry" '
#  'meaning lean brisket. i had coleslaw, my husband had beans, and we were '
#  'given a baggie of 4 slices of white bread. cafeteria style...more',
#  ' american, bar, vegetarian friendly the staff were very attentive and they '
#  'gave me a good wine recommendation, a very good service. i had the salmon '
#  'and it was delicious and ate every bite and no trouble dealing with gluten '
#  'free. some of the food options were unusually i would...more',
#  ' japanese, sushi, asian i was very pleasantly surprised by the quality of '
#  'food and ambiance of this establishment, felt very japanese.will be back.',
#  ' italian, pizza, vegan options this is your typical american-italian eatery '
#  "in that the cuisine is really more american's idea of what italian food "
#  'should be like, rather than authentic italian.\n'
#  '\n'
#  'if find most of the dishes pretty blah, although i do appreciate that they '
#  'use a more flavorful cheese...more',
#  ' japanese, sushi, asian i love oto sushi.  i go there at least once a week '
#  'and can not recall ever getting a meal i did not thoroughly enjoy.  the menu '
#  'is full of elegant and delicious choices.\n'
#  'the prices are great.  the service is immaculate, helpful and not...more',
#  ' mexican, latin, spanish the food here has been everything from terrible '
#  '(tortilla soup) to wonderful (fajitas). recently, they also offer indian '
#  'food, which is very odd. the best thing on the menu is the coronarita. stick '
#  'with that and some chips and salsa.',
#  ' american, cafe, vegetarian friendly welcoming and trendy setting with '
#  'creative twists to even the most basic dish! great meal, great '
#  'atmosphere—and the owners and staff couldn’t be more cordial.  every item is '
#  'beautifully presented and flavorful. you can stop in for a latte, or a full '
#  'meal and won’t...more',
#  ' italian, vegetarian friendly, vegan options when with my daughters and '
#  'nefew. \n'
#  'great food!\n'
#  'great service!\n'
#  'great prices!\n'
#  'all home cooked meals.\n'
#  'friendly waiter.\n'
#  'small and quaint atmosphere.',
#  " american, vegetarian friendly, vegan options we found bob's right next door "
#  "to our hotel so it was convenient and we didn't have to drive any more that "
#  'day.  the place was fairly busy but we were seated right away.  i opted for '
#  'a glass of water, my grandson took on...more',
#  ' italian, pizza, vegetarian friendly i just wanted to give you some feedback '
#  'regarding my last visit on thurs 12/26. it was my 30th birthday and i went '
#  'to you guys because you were my favorite restaurant. \n'
#  'however i was very disappointed with the service that night and will '
#  'probably...more',
#  ' asian, vietnamese, vegetarian friendly the restaurant is a nice place with '
#  'good food. the servings of any food are huge but they are tasty. the service '
#  'is quick and restaurant is clean. the place is worth the money.',
#  ' italian, vegetarian friendly, vegan options my husband and i were in town '
#  'for the night to run the katy half marathon the next morning. not familiar '
#  'with the area and wanting to carb load, we looked into nearby italian '
#  'restaurants. we were pleasantly surprised to find this gem. we had...more',
#  ' mexican, latin, bar lovely food, got pushed a special which turned out to '
#  'be $30 more than my original order. so that was a little annoying, $55 for a '
#  'tiny piece of salmon, a shrimp, one scallops and some fingerling potatoes '
#  'not worth it. everything else was tasty...more',
#  ' french, international, european four of us for dinner.  all of us ordered '
#  'the seafood ravioli which were like little ethereal pillows.  so good.  also '
#  'had seared foie with toast points that was excellent.  crab cakes are huge, '
#  'but a bit bland for me.  someone else had duck with...more',
#  ' mediterranean, middle eastern, vegan options in the area on holidays and '
#  'visited today for dinner. the food was fantastic and the staff were lovely '
#  'and very patient in explaining how it worked. would definitely recommend',
#  ' american, bar, cafe this place is wonderful. we tried it for the first time '
#  'late this summer and have been there a couple of times now. friendly staff, '
#  'great atmosphere (feels like you left the pacific northwest for a bit!) and '
#  'the food is excellent. we went specifically...more',
#  " italian, pizza, vegetarian friendly i really don't enjoy italian places "
#  'since i a gluten free, but there are very accommodating.  there is gluten '
#  'free penne pasta with any of their pasta meals, gluten free pizza crust and '
#  'knowledgable employees.  i settled on soup and salad, but the rest of...more',
#  ' seafood, european, spanish this place is like the tardis of restaurants.  '
#  "you walk in and it's a nice little bar, but then continue on and there are 3 "
#  'dining rooms that altogether must hold 200 people.  they have good tapas '
#  '(great grilled octopus), a full menu (with about...more',
#  ' american, seafood, vegetarian friendly this is one of the restaurants high '
#  'on our list when we moved to the area in 2018, but hadn’t gotten there until '
#  'tonight.  i read a recent pretty favorable review in the times union so the '
#  'multiple changes in ownership and chef didn’t phase...more',
#  " american, international, vegetarian friendly have been to pj's many times "
#  'in person and through delivery. food is always fresh and tasty and very '
#  'flavorful. have had all the breakfast items as well as their cheese steak '
#  'which is great for lunch. would highly recommend!',
#  ' american, greek, diner we were recently at the rainbow diner for dinner.  '
#  'we have been here many times before.  the food this week was exceptionally '
#  'good.  the food was delicious, and served nice and hot.  i ordered a seafood '
#  'dish, which was cooked perfectly.  the bread pudding was...more',
#  ' american, bar, pub cool place, lots of craft beers on tap, no full bat. '
#  'limited food but it was good. staff was awesome,  cozy funky little place.',
#  ' german, european, vegetarian friendly food was pretty good but it’s '
#  'unbelievably loud. felt like a cafeteria with people screaming over one '
#  'another. made it hard to have a conversation, which kind of ruined the meal. '
#  'acoustics could be fixed. 😒',
#  ' american, steakhouse, gluten free options this was my 3rd time here for '
#  'brunch and i will always recommend. amazing food, great customer service and '
#  'i had the pleasure of jacob m being our server he made our dining experience '
#  'outstanding. highly recommend',
#  ' mediterranean, greek, vegetarian friendly this place has great food. we got '
#  'our food quickly, staff was friendly, atmosphere casual, and we did not feel '
#  'rushed at all. plus the water tastes good.',
#  ' italian, vegetarian friendly, gluten free options on a long weekend we '
#  'decided to go to this restaurant to have a relaxing and quiet lunch. the '
#  'food was good, we had 3 different appetizers the service was a little '
#  'overwhelmed overall this is a very goood restaurant',
#  ' italian, pizza, vegetarian friendly good pizza great wings and fried '
#  'calamari \n'
#  'they use semolina and it always burns on the bottom of the pizza but '
#  'otherwise a pretty good pie',
#  ' french, gluten free options, vegetarian friendly this is one of my favorite '
#  'restaurants in kirkland. great view over carillon marina and lake '
#  'washington. always had excellent service. love their french onion soup.',
#  ' french, vegetarian friendly, vegan options wonderful restaurant, pleasant. '
#  'the menu at daniel is a french culinary heritage. the food  is amazing.',
#  ' italian, pizza, vegetarian friendly the pizza was okay, but nothing '
#  'special. all we had heard was that we had to try this place because the '
#  "pizza was amazing. i'm still not convinced. i ordered a large pizza for "
#  'takeout and it cost almost $27. the dough was bordering on...more',
#  ' american, seafood, vegetarian friendly we go to lobster shop every year for '
#  'valentines and it never disappoints. make sure you book in advance! the '
#  'taste menu is perfect and the service is even better.',
#  ' american, bar, gluten free options they were not prepared for new year’s '
#  'eve rush. had reservations for 7 waited 30 minutes before asking what the '
#  'hold up was. after i complained they sat us. took 35 minutes before any food '
#  'arrived. they brought appetizer and main course at same time....more',
#  ' italian, vegetarian friendly, vegan options novellis is a really nice '
#  'classy restaurant. once i stepped foot into it the owners were very sweet '
#  'and greeted us very well. we sat at a nice table by the fireplace and our '
#  'waiter was great! the food was the best part. i truly...more',
#  ' mexican, latin, vegetarian friendly there are so many choices for mexican '
#  'food on the border, but we decided to try something new . . .\n'
#  '\n'
#  'we are very glad to have tried andale.  there was live music that night with '
#  'a 30 minute wait for a table, but we...more',
#  ' japanese, barbecue, sushi our covenant group gets together once a month or '
#  "an outing and/or dinner. yesterday we went to the 'escape room' located on "
#  'fm 2920 in spring then for dinner at "q-shi bbq / bistro". we had '
#  'reservations at q-shi and elected to sit in the...more',
#  ' french, gluten free options, vegetarian friendly i enjoyed an amazing '
#  'business lunch with lobster bisque, crusted sea bass and pecan bread '
#  'pudding. the food was fantastic and service above expectations!',
#  ' american, deli, vegetarian friendly this is a fabulous lunch spot and the '
#  'sandwiches so awesome we came here 2 days in a row while visiting from '
#  'michigan. i talked my daughters ( who said they don’t like reubens) to taste '
#  'mine and today all three of us are eating...more',
#  ' irish, bar, pub the place reminded me of an irish pub i visited in dublin.  '
#  'i had the reuben which was out of this world!  it was loaded with meat and '
#  'the rye was perfect.  the only thing lacking for me was the dill pickle.',
#  ' chinese, asian, seafood would give 4.5 if i could! we came here on a recent '
#  'sunday for dim sum. we parked down the street not knowing there was a small '
#  'parking lot next to the restaurant, but the restaurant lot was full as we '
#  'walked by. we arrived...more',
#  ' american, bar, pub absolutely love their fries. great seasoning and cooked '
#  'just right. good salads and burgers. worth a visit.',
#  ' american, steakhouse, vegetarian friendly this is like many other capital '
#  'grille a winner. great food, even better service. they really care about '
#  'special wishes. also i like the wine pad with all the information about your '
#  'wine',
#  ' irish, bar, pub colby ave. has a lot of restaurants including the irishmen. '
#  'my best advice is to consider it a good place for a beer, but skip the food '
#  'and keep walking to one of the many restaurants on colby. my wife and i met '
#  'another couple...more',
#  ' american, bar, vegetarian friendly signed up for the valentines day special '
#  'menu dinner.   had been in previous years and it "was" wonderful.     in the '
#  'last few months have noticed during several dinners and lunches it was '
#  'having problems.  quality of food unpredictable and never enough '
#  'staff.........very slow service.\n'
#  '\n'
#  'well...more',
#  ' mediterranean, greek, vegetarian friendly experienced terrible service at '
#  'this place. came on a sunday for lunch with my family and after we were '
#  'taken to our table, no one ever came to service. all the waiters were '
#  'gathered together watching a soccer game on a cell phone by a...more',
#  ' steakhouse, american, seafood 8 of us went to try dee lincoln primr. was '
#  'very good steak but not better than all. had  char broiler oysters for '
#  'appetizer. it was terrible. very fishy. strong odor. great service. very '
#  'expensive. also should include something to do with steak.',
#  ' american, bar, pub the food here is really good and the portions are great. '
#  'there are plenty of tvs to watch lots of sports at the same time. it can get '
#  "loud but that's what a sports bar is right? the best thing about this place "
#  'is that...more',
#  ' mexican, latin, central american this place is a must if your a taco fan.  '
#  'i think it’s the best place to satisfy a mexican craving.  it’s worth the '
#  'wait as it will please your tastebuds and you will be back for more. price '
#  'wise i think it’s great value...more',
#  ' american, vegetarian friendly, vegan options what a great place!  the decor '
#  'was classy and comfortable, and the vibe was intimate. our waiter, rick, was '
#  'extremely friendly and knowledgeable about the menu and made excellent '
#  'suggestions.  he also paced the meal well and was attentive without being '
#  'intrusive at all.  and...more',
#  ' asian, thai, sushi was take to this local asian restaurant.  it is a '
#  'perfect small "hole" in the wall location.  i had the mongolian beef and i '
#  'was amazing.  only con was they gave me spice level options of 0-5.  i said '
#  'five three times, while waitress corrected...more',
#  ' american, cafe, vegetarian friendly tomato bisque was amazing.  good '
#  'service, nice location overlooking boardwalk and beach.  good hamburger, not '
#  'outrageously priced.  i would definitely be back.',
#  ' american, bar, pub wait staff was marvelous!---however dinner left a lot to '
#  'be desired-----food was apparently just piled on plate----dinner was $ but '
#  'had none of the extras, salad rolls.\n'
#  'cannot say this is a place i would return to',
#  ' gastropub, american, bar tremendous amount of drink and beer selections. '
#  'the food is a smaller menu. we ordered pork and beef tacos and they were '
#  'delicious! the smoked pepper had distinct smoky flavor with a slow spice '
#  'hotness. somewhat of a roadhouse scene.',
#  ' american, bar, pub we have eaten at pearl a handful of times but last night '
#  'it really was outstanding....the mixed cocktails to start. the freshest '
#  "oyster we've had in a long long time. small plates we had the delicious "
#  'octopus, mushrooms and shrimp. i just for the filet...more',
#  ' american, bar, seafood we were out for a drive and we were in poughkeepsie '
#  'so we decided on river station. we usually go in warm weather so we can sit '
#  'outside but we love their chowders so we figured we’d give it a winter try. '
#  'turned out to...more',
#  ' italian, american, bar around $40 for the whole pie but you can do 50:50 on '
#  'the topping for to get 2 different pies. or order by the slice if you '
#  'prefer. pizza are huge 20 inches. decent drinks choice & nice touch with the '
#  'cucumber water',
#  ' seafood, vegetarian friendly, vegan options we met our daughter and her '
#  'boyfriend for brunch here. reserved a window seat and had a beautiful view '
#  'of the water on a rare sunny day ! \n'
#  'service was great and so was the food!',
#  ' italian, pizza, fast food good pizza, good burgers, good prices! \n'
#  "we had a stay next to mike's pizza and it was perfect to have this place "
#  'next to us.',
#  ' american, cafe, vegetarian friendly upon reading this review, please don’t '
#  'tell anybody about this secret ocean city gem.  it’s the cheers of breakfast '
#  '& lunch in oc.  from eggs to salads, scrapple to turkey specials, creamed '
#  'chipped beef to cheesesteaks, it’s always quality food served with '
#  'personality.  see you...more',
#  ' american, asian, fast food this restaurant burned on july 12, 2018, and it '
#  'is still boarded up and has a security fence all the way around it.  it has '
#  'been closed for 8 months - i cannot imagine any business being closed for '
#  'that long and then start back...more',
#  ' american, seafood, cajun & creole nothing made my birthday more special '
#  'than spending it here, with some of the people i love and cherish the '
#  'most..i love this restaurant!..they have never disappointed me..the food was '
#  'superb and they have some of the best customer service around..',
#  ' american, diner, vegetarian friendly the triangle diner is the place to go '
#  'for breakfast if you are anywhere near saratoga springs, ny. the servings '
#  'are plentiful, the menu diverse and the food is simply delicious! from '
#  'french toast and pancakes and biscuits and sausage gravy, to corned beef '
#  'hash,...more',
#  ' american, bar, pub i was not looking for a great culinary experience when a '
#  'group of friends and i decided to venture into well 80.  i am not really a '
#  'beer drinker but i am a fan of seared animal flesh with a side of anything '
#  'that will...more',
#  ' american, vegetarian friendly, vegan options my husband and i absolutely '
#  'love the food, the atmosphere and the staff! the food is hands down the best '
#  'that we have ever had! we highly recommend.',
#  ' italian, pizza, gluten free options the bread is always the best! we had '
#  'the prosciutto flatbread, and it was so savory that my mouth watered. the '
#  'special of the day, the verde trio, had scallops, shrimp, and crab meat in a '
#  'white wine sauce. it was delicious and was just...more',
#  ' indian, pakistani, vegetarian friendly we had the grilled lamb which came '
#  'with potatoes and the chicken biryani which came with basmati rice. the '
#  'potatoes were not flavorful but the basmati rice with curry was. the meats '
#  'were both flavorful. higher prices are justified by the bigger portions. one '
#  'thing...more',
#  ' american, steakhouse, gluten free options john howie steak is an '
#  "outstanding that is outstanding in virtually every way.  that said it's also "
#  'very expensive but, on special occasions, worth it.  the restaurant adds an '
#  'automatic 20% service charge to the entire bill that is not shared with the '
#  'staff.  that...more',
#  ' seafood, european, spanish this spanish/basque restaurant is in the '
#  'ironbound district but not on ferry street. that may make it more of a '
#  'destinations for locals; i did get to speak spanish with some men, born in '
#  'galicia, eating at the bar. all entrees come with a thick,...more',
#  ' chinese, sushi, asian first time for lunch here, i was anxious to find out '
#  'the difference between lunch and dinner menu. the standard cooked items are '
#  'pretty similar. the sushi and seafood selection selection is a lot less in '
#  'lunch. there is no peking duck wrap and the...more',
#  ' american, bar, diner the "hot mess" was fantastic!\n'
#  'great waitstaff good breakfast vibe.\n'
#  'the tv memes are hysterical! 🤣🤣',
#  ' mediterranean, vegetarian friendly, vegan options dinner with friends be '
#  'for a show. the four of us ordered different entrees an each on of us was  '
#  'delighted with our choices. waiter was pleasant and knowledgeable. it was an '
#  'enjoyable experience. we will be back.',
#  ' american, vegetarian friendly, gluten free options my wife and i celebrated '
#  'our 30th wedding anniversary with our family this is the 3rd time here and '
#  'each time we are amazed at how good the service and the food are, especially '
#  'the steak asada with the enchilladas.',
#  ' american, steakhouse, bar awesome customer service and great steak. always '
#  'a good location for a business meeting. you must try!',
#  ' bar, american, pub i had the grilled chicken with their fabulous sweet '
#  'potato. of course, can’t skip the bread and side salad. the salad was crisp '
#  'and cold, just the way it should be. the bread was warm and delicious '
#  '(always my downfall). the chicken was moist and...more',
#  ' american, bar, vegetarian friendly the hostness greeted us with a wonderful '
#  'smile. our server alyssa was friendly and efficent. the food is always '
#  'delicious and the restroom was clean.',
#  ' irish, bar, pub the traditional bar singing, dollar bills on the wall, fun '
#  'staff great drinks. fish and chip and the shepherds pie are my suggestions.',
#  ' barbecue, american, southwestern we went on the evening of the 22nd of '
#  'january 2020. we were late enough they were out of somethings, but what they '
#  'had was very good. we got the venison sausage, pulled pork smoked turkey and '
#  'the brisket. all the meats were tasty. we...more',
#  ' american, italian, vegetarian friendly very nice place to to go for a meal. '
#  'they have great happy hour and wonderful servers and very nice atmosphere. '
#  'food is tasty, love to come back and try more.',
#  ' american, fast food, diner white manna has been around since 1939, serving '
#  'award winning sliders; a mini burger that can be eaten in just two or three '
#  "bites. but what's even more fun is that the building itself can only hold "
#  'around fifteen customers, so it is not unheard...more',
#  ' chinese, asian, vegetarian friendly i love asian dumplings and this place '
#  'did not disappoint. located in the back of an asian inspired mall on main '
#  'street made for an adventure finding this restaurant decorated in a '
#  'welcoming oriental motif. romantic for a first date and subsequent date '
#  'nights. the...more',
#  ' italian, european, sicilian a very little restaurant but they provide '
#  'amazing food and they are the nicest people you will meet. loved it, would '
#  'happily come again when in ny!',
#  ' italian, spanish, vegetarian friendly we stayed overnight in kennewick and '
#  'discovered this by accident. great bistro run by father and son. food was '
#  'great and restaurant is small enough that it doesn’t get noisy. wines by the '
#  'glass were a little on the pricey side but were wonderful. we...more',
#  ' american, international, vegetarian friendly we just had lunch but the '
#  'selections and preparation were very good. i had a fried egg blt that was '
#  'quite tasty, my companion had the chicken sammy and liked ti very much, my '
#  'wife has a side of grilled broccolini that was excellent, and...more',
#  ' european, vegetarian friendly, gluten free options the food is delicious, '
#  'atmosphere is very appealing.  i thoroughly enjoyed my dinner at salis '
#  'bistro.  will definitely be back.',
#  ' american, diner, gluten free options if your in spokane, this is a must go '
#  'place. set in a historical railroad dining car, the place is small but with '
#  'great food. primarily specializing in breakfast, there are a variety of '
#  'items on the menu. my wife had a burger with fries,...more',
#  ' asian, thai, vegetarian friendly just found this little gem in new york. '
#  'what a find food was fantastic and service was amazing. my friend and i had '
#  'the $11 lunch special which was more than enough food . i had my favorite '
#  'green thai curry and absolutely loved it....more',
#  ' steakhouse, latin, argentinean always enjoy eating at asado. it’s my wife’s '
#  'favorite.  it’s not cheap...but mostly worth it.    don’t understand that 5% '
#  'service charge tho.',
#  ' american, bar, vegetarian friendly make sure you have a reservation as we '
#  'showed up at our appointed time and there were people waiting for a table. '
#  'we basically sat right down to the "looks" of them....\n'
#  'even though it was a monday night, the place was packed and '
#  'loud...the...more',
#  ' mexican, american, southwestern this place is on s. austin on manchaca. it '
#  'is so good, better than salt lick. the line is long at times but not nearly '
#  'as long at franklins. it’s reasonably priced and they give you plenty to '
#  'eat. my favorite bbq in town.',
#  ' italian, pizza, neapolitan our family has become snobby when it comes to '
#  'pizza.  chain stores don’t cut it.  this pizza wins an award!  we all loved '
#  'it.  the sauce and toppings were fresh, and the crust was perfect.  '
#  'spectacular!',
#  ' mexican, southwestern, vegetarian friendly we came after the lunch rush '
#  'ended and were immediately seated.  it took awhile to figure out what to '
#  'order (lots of unique taco options including oxtail) but we were quite happy '
#  'with our choices:\n'
#  '\n'
#  'blackened fish tacos - three came on the plate with...more',
#  ' american, steakhouse, bar arrived 10 minutes early. rude hostess. table was '
#  'ready. made us seat in cold lobby after we requested to be seated and wait '
#  'for the rest of our party. ignored other guests while speaking to fellow '
#  'employees. good food though.',
#  ' italian, pizza, vegetarian friendly looking for great pizza, amazing '
#  'salads.....and great service? need to try it out.  and all done with great '
#  'service.',
#  ' italian, pizza, vegetarian friendly good food and excellent service.\n'
#  '\n'
#  'we arrived for an early dinner after some errands and within the hour there '
#  'must have been 10+ people waiting as every table was full.\n'
#  '\n'
#  'we were a family of five, shared caesar salad, meat lovers pizza, shrimp '
#  'pasta and...more',
#  ' italian, pizza, vegetarian friendly no matter who i introduce to nick’s '
#  'pizza, they always want to go back for more! excellent salads and calzones, '
#  'too! my favorite pizza in fh.  thin crust, fresh mozzarella, and excellent '
#  'sauce. great options for toppings, too.more',
#  ' italian, pizza, vegetarian friendly we have our regular places to eat in '
#  'lubbock. today we found a new regular place. this place was incredible. the '
#  'calzone was amazing. i am usually not a calzone guy, but since we were not '
#  'splitting a pizza i decided what the heck. i...more',
#  ' american, seafood, bar house wines $5 and some really good wine for only '
#  '$6. the fried pickles are the best! very lightly breaded, not greasy at all. '
#  'i had a bowl of the crab chowder - excellent.  my husband had the stuffed '
#  'flounder special, and it was gorgeous....more',
#  ' american, gastropub, pub quiet night after the recent "big snow". good '
#  'bartender stayed on top of everything. friendly (but small) crowd. nice '
#  'wines by the glass. burger and a roast pork sandwich were prepared to order '
#  "and very good. i'll return when there are more people to comment...more",
#  ' american, bar, cafe great brunch spot that has been around for a long time '
#  'right next to cornell university.  try making a reservation or prepared to '
#  'wait during weekend brunches.  very good espressos upstairs while you wait.  '
#  'good bloody marys as well,.',
#  ' american, bar, vegetarian friendly had a celebration with our grandkids.  '
#  'had a great time exploring the restaurant with my grandkids and the food was '
#  'good.',
#  ' american, vegan options, vegetarian friendly i absolutely love shopping '
#  'here at wegmans in cherry hill and mount laurel.\n'
#  'great products, great quality, vast selections, reasonable prices\n'
#  'the staff is friendly, helpful and knowledgeable of the store, stock, and '
#  'products.\n'
#  'when i have the time i can spend hours browsing and...more',
#  ' caribbean, latin, spanish i have not been here in quite some time.  they '
#  'had a mediocre buffet and they now have a liquor licence.  they also '
#  'remodeled. i wonder if the ownership changed.  they will not give you '
#  'separate checks either.  the red sangria was and the music...more',
#  ' mexican, latin, vegetarian friendly love this place. the food is fantastic '
#  'and the service is great! our server nicknamed coco introduced us to the '
#  'menu and made us aware of their famous dish molcajete, churrasco, carne '
#  'asada, grilled chicken, pork chop, mexican sausage & grilled shrimp served '
#  'in a...more',
#  ' seafood, italian, vegetarian friendly i loved all of the food at caffe '
#  'aldo. i walked in and the restaurant was beautiful. the presentations of all '
#  'of the plates were gorgeous. i especially liked the crab cake appetizer. the '
#  'calamari appetizer was light and airy, and the zucchini fries were...more',
#  ' american, seafood, gluten free options i had a salad and steak and '
#  "should've stopped at the shared large order of mussels.  by the time i'd "
#  'savored my share of the 40 or 50 mussels and sopped up the accompanying '
#  "sauce' sauce with the supplied bread, i really didn't have room...more",
#  ' bar, american, vegetarian friendly my past dining experiences at bis on '
#  'main have always been positive and i’ve always raved about it to friends and '
#  'colleagues of mine; however, this last experience just before the holidays '
#  'changed my mind.  the older gentleman (host?  owner?) who checked us in '
#  'should...more',
#  ' japanese, sushi, asian i have been a number of times and have never been '
#  'disappointed! the food is excellent, the service is excellent and the spicy '
#  'cocktail is excellent, the experience is like no other sushi restaurant in '
#  'houston.',
#  " mexican, southwestern, latin i have eaten at kiki's time and again and "
#  'never get tired of their delicious plates. my favorite are the tacos but the '
#  'mole is just as good. you gotta try their salsa with any dish.',
#  ' american, vegetarian friendly, vegan options ok, you can see by my earlier '
#  'review that this is a good place overall, but i just drove 2 hours to here '
#  'to get their ludricrous wings. i have eaten ghost peps, scotch bonnet, you '
# ...
#  'only usually large brewery offerings and no...more',
#  ' pizza, fast food, vegetarian friendly make your own sallad or pizza or pick '
#  'on of their favourites. no matter what you end up choosing, you will be '
#  'surprised on how fast you will be served. the staff is friendly and service '
#  'minded',
#  " american, southwestern, barbecue rudy's was great as always. moist brisket "
#  'was perfect. pulled pork very good also. sauces very good and compliment the '
#  'meat. cream corn was great.',
#  ' bar, vegetarian friendly, vegan options pricey, but delicious food. the '
#  'mixed drinks were good, but small. the atmosphere was dark, loud and '
#  'crowded, but they somehow pulled off a cozy feel despite this. will go '
#  'again! once my wallet recovers.',
#  ' american, vegetarian friendly, vegan options nice lunch, cozy space a bit '
#  'chilly the day we sat in but great service and food.\n'
#  'would definitely return to try something else.',
#  ' japanese, seafood, sushi for a buffet they do a good job. there is sushi, '
#  "other asian food, american food, lots of options at a decent price. i'm not "
#  'a fan of buffets but this one was good and worth trying to get fresh '
#  'seafood.',
#  ' steakhouse, argentinean, latin there was hair in my food and i told the '
#  'manager and they said it wasn’t their fault but i’m bald and my kids where '
#  'no where near my food and my wife was in the restroom.',
#  ' asian, vietnamese, vegetarian friendly what a delightful surprise! passing '
#  'through baylor territory, we thought we would grab a quick bite. we happened '
#  'on this spot and were blown away. it was delicious. the service was quick '
#  "and very friendly. can't wait to visit again.",
#  ' italian, vegetarian friendly, vegan options kenny´s italian kitchen is a '
#  'great restaurant. their lasagne and carbonara are the best! one of my '
#  'favorite italian restaurants in the city.',
#  ' indian, asian, vegetarian friendly the absolute best indian food i have '
#  'ever had.  tandoor topli na paneer was amazing! fine dining with great decor '
#  'and fabulous service. highly recommend!',
#  ' seafood, mediterranean, greek we have been going to oceanos from their '
#  'beginning in 2005 and have never had a bad meal. it is our “go to” '
#  'restaurant for upscale dining in bergen county.  kumamoto oysters, horiatiki '
#  'salad, lavraki and their delicious desserts are our regular selection. '
#  'recently, we...more',
#  ' mexican, latin, spanish food was good but prices charged didn’t match the '
#  'menu. we don’t speak spanish so there was a language problem and didn’t '
#  'bother trying to ask why we were charged so much. nice atmosphere but '
#  'probably wouldn’t recommend unless you speak spanish.',
#  ' american, diner, vegetarian friendly this place is almost always busy & a '
#  'favorite of many locals & others. (be prepared to wait a while if you go do '
#  "when it's busy!) everything that we & our friends have had there has been "
#  'good. nice service. decent prices. good variety.',
#  ' italian, pizza, vegetarian friendly very nice pizza and ravioli. the bread '
#  'was very delicious. wie enjoyed this eveinig there , we will be coming back!',
#  ' italian, pizza, vegetarian friendly meeting room was in a quiet space.  had '
#  'a large screen tv which one could cast to.  service was very good, we were '
#  'not serviced and forgotten!  very attentive to coffee refills which was '
#  'appreciated.  food is high quality and generous serving size.',
#  ' american, bar, barbecue it breaks my heart to write this review... but it '
#  'must be done.  \n'
#  '\n'
#  "today, february 14, 2020, i decided to take my wife & daughter to fat bob's "
#  'smokehouse for a relaxed valentines dinner.  my wife ordered baked haddock, '
#  "that wasn't fully cooked, daughter ordered...more",
#  ' mexican, southwestern, latin delicious food and quick friendly service. '
#  'can’t wait to come back next time i drive through bellingham:)',
#  ' american, bar, vegetarian friendly had a large group. i ate the fish n '
#  'chips which i was not impressed with. left most of it there. very bland and '
#  'no flavor. the nutty manhattan was outstanding',
#  ' american, diner, vegetarian friendly the fontainbleau diner is a great nj '
#  'diner -- with a diverse menu and breakfast all day long.  the fries and '
#  'gravy were a nice addition to my veggie omelette.  the coffee was robust and '
#  'not lame mud-water like some diners.  always a good meal!',
#  ' american, irish, bar we had 7 people for lunch. the menu is extensive, '
#  'definitely something for everyone. our server was attentive and friendly. '
#  'when the check arrived we examined it quite closely because we thought "it '
#  'can\'t be this inexpensive!" will definitely return and recommend to all '
#  'our...more',
#  ' mexican, latin, spanish while on business, i found about this restaraunt a '
#  'little too late, before leaving laredo. however, that may have been a good '
#  'thing cuz i would have spent all my money there trying each plate! wow, the '
#  'food is authentic, fresh, and great tasting. prices...more',
#  ' italian, vegetarian friendly, vegan options thanks to our server john for '
#  'making our first first a pleasurable one!\n'
#  '\n'
#  'sunday gravy.... took me back to a time when i was young and my grandma '
#  'would make the best gravy with all the best meats!!! rigatoni’s my '
#  'favorite!!\n'
#  'my date had the...more',
#  ' american, wine bar, vegetarian friendly the brisket was superb. roughly $32 '
#  'but well worth every dollar. my only.gig was where we seated. view was nice '
#  'but space/table was designed for a larger party making it ackward for just 2 '
#  'people. either way the staff is awesome, the ambiance is romantic...more',
#  ' mexican, southwestern, vegetarian friendly waco has some fabulous '
#  'restaurants! and this one is well worth a "10", also!  really super good and '
#  'great food, service, ambiance, and all around experience! but again bring '
#  'your appetites or take some of it home or split a meal because portions are '
#  'huge!!!...more',
#  ' mediterranean, middle eastern, vegetarian friendly really great tabouleh '
#  '(salad) but the hummus had no taste. the dessert (keskul) was fine but meant '
#  'to be shared, and the eggplant had too much oil. overall think the '
#  'presentation was fabulous but food quality was ok.',
#  ' steakhouse, american, bar i have gone here for years and i have always '
#  'loved it but tonight i waited 15 minutes for a server and after asking we '
#  'received a server who did not apologize once for the wait and came over '
#  'extremely sarcastically and rude. when asked...more',
#  ' american, bar, brew pub great food\n'
#  'great service\n'
#  'great atmosphere \n'
#  'the nachos is a must have when you are there.\n'
#  'we will be back!',
#  ' caribbean, jamaican, vegetarian friendly make stupid mistake placing and '
#  'have the nerve to be arguing with customers, not doing job correctly short '
#  'african looking bald headed woman',
#  ' american, wine bar, bar my wife and i have been to wine on third several '
#  'times and have always found the place to be convivial.  the food is great '
#  "and wine is, well what can i say, it's in their name.  great place.",
#  ' american, bar, pub interesting menu full of tasty choices. good looking '
#  'pizzas and a really\n'
#  'wonderful salad. beer was great as well. nice place to visit.',
#  ' seafood, mediterranean, european my wife, daughter, and i stopped for '
#  'dinner. due to dietary constraints my daughter ordered salmon without any '
#  'salt, marinades or oil. the waitress was extremely tentative and helpful. '
#  'when the food arrived my daughter could not eat it because it was too salty, '
#  'the...more',
#  ' american, vegetarian friendly, vegan options great location just off the '
#  'main road in princeton across from the university... they had a great '
#  'selection of pizza with many veggie options... the food was delicious and '
#  'was very reasonably priced... i will def come back...',
#  ' american, international, vegetarian friendly i enjoy going here at any time '
#  'of day because there are lots of everyday and gourmet choices within easy '
#  'reach a few steps away from the newly renovated market cafe seating area.  '
#  'if you love sushi, going very early or very late might not...more',
#  ' mexican, latin, spanish little hide a way that i never even knew was here '
#  'in puyallup.  i have drove past this placed every day for yearfs and never '
#  'had the courage to go in.  i finally had the nerves to go inside and it is '
#  'very rough inside...more',
#  ' italian, vegetarian friendly, vegan options i frequent the capital district '
#  "of ny and ferrari's is a must stop for eating every time, no matter what "
#  "else i've go going on while i'm in town. you walk out of here hungry there's "
#  'something wrong with you. the amount of food is...more',
#  ' american, bar, pub not sure how this place has 4.5 stars here on '
#  'tripadvisor (or any review site).  maybe because of the beers, which are '
#  'ok.  not better than any other small commercial brewery though.   we ordered '
#  'a range of food.  pub house fries, quesadilla, po town cheesesteak,...more',
#  ' pizza, italian, vegetarian friendly i have to say i was disappointed. '
#  'ordered a small margarita pizza ($16.00)...have read glowing reviews and was '
#  'awaiting an exceptional pie. what i got was an average at best pizza.. '
#  'cheese was ok...just not enough...crust better than average...but the most '
#  'important main ingredient failed...more',
#  " irish, bar, pub hailey's is a great irish pub, we stopped in for lunch on "
#  'an early saturday afternoon,  we were pleasantly surprised to see a band '
#  'setting up. in edition to a great afternoon of live music, the food was '
#  'amazing. my prime rib was delicious as...more',
#  ' italian, vegetarian friendly, gluten free options my mother, daughter and i '
#  'traveled to white plains for the 1st time to look at pace u.  we went to '
#  "dinner on valentine's day.  they had a special menu for the evening.  we had "
#  'a mozzarella, sausage, basil roll appetizer.  the handmade lobster '
#  'ravioli...more',
#  ' italian, vegetarian friendly, vegan options wonderful 5 course italian byo '
#  'experience. was a little disappointed with some of the dishes, but others '
#  'were outsdtanding. the mussels in calabria chili was bland- was expecting '
#  'some spice, but was lacking in flavor. the kale salad was also very bland. '
#  'the pasta dishes...more',
#  ' pizza, italian, vegetarian friendly went there with my wife and friends and '
#  'really enjoyed it.  not our first visit, but the best one yet.  \n'
#  'ordered three items:  calamari(with no tentacles), large white with broccoli '
#  'and a vodka sauced pie.  all three items were excellent and the sauce with '
#  'the...more',
#  ' italian, vegetarian friendly, gluten free options as always, we were '
#  'thrilled with  our meal and the attention we received....\n'
#  'this  is a byob joint - and there is a liquor store right next door!  the '
#  'selections are wonderful and william is our favorite server! the most '
#  'appealing thing - they will...more',
#  ' indian, asian, vegetarian friendly pure vegetarian hotel in edison\n'
#  'restaurant location is good and parking facilities available\n'
#  'food quality is average\n'
#  'variety of food options\n'
#  'staff service is below par, not customer oriented\n'
#  'food can be ordered in uber eats, door dash',
#  ' american, vegan options, vegetarian friendly what a great find\n'
#  ' two of us had pizzas, loved the crust, fresh ingredients\n'
#  ' the guys had calzones and throughly enjoyed them as well. will be back',
#  ' peruvian, latin, seafood we went there or the ceviche. it was very good. '
#  'but the restaurant itself its not very appealing. neighborhood also is king '
#  'of seedy. delivery might be a better options if you mind these things',
#  ' american, mediterranean, italian the bistro has moved to elm and magnolia. '
#  'i went for girls brunch. venue is cute, food was delicious, service was good '
#  'although i was a little surprised the wouldn’t split the bill.',
#  ' polish, european, eastern european this is absolutely excellent homemade '
#  'polish food, surprisingly in trenton...it was like visiting a polish '
#  "grandmother  the restaurant did not look great from the outside, but don't "
#  'let that stop you.  inside, it is beautiful, with dark wood and '
#  'butter-colored walls, with photos of eastern...more',
#  ' indian, vegetarian friendly, vegan options after seeing the great reviews, '
#  'i expected some very good and authentic cuisine. not the case!\n'
#  'just ehhhh.',
#  ' mediterranean, greek, vegetarian friendly we found this place by accident '
#  'driving by one day and said we should try it next time. we went to the kafe '
#  'side it was amazing. from customer service when you first walk in to the '
#  'deliciousness of the food we loved it. it...more',
#  ' vegetarian friendly, vegan options, gluten free options beautifully '
#  'appointed interiors, outstanding, if not stunning. \xa0nice garden. \xa0the '
#  'service was great. \xa0our experience was slightly restricted by their wine '
#  'choices, all coming from the same nj winery. \xa0must add that wine was '
#  'good, both white and late harvest for dessert. \xa0the seafood and...more',
#  ' american, southwestern, bar had both my dinners here.  the burger was '
#  'really good and so where the fries.  the 2nd night, tried the pork tacos, '
#  'excellent!  rusty nail was done really well.  the mgr staff were very '
#  'accommodating and pleasant.  there dinner menu is much more limited '
#  'than...more',
#  ' american, bar, seafood we came here a little late on a wednesday.  dining '
#  'room closed because of lack of customers.  we were seated in the bar area, '
#  'which was fine.  however, it is entirely annoying to be stuck with hi-top '
#  'tables and chairs.  it seems to be a...more',
#  ' mexican, southwestern, latin my husband and i moved back to upstate ny '
#  'after living 6 yrs in new mexico. this restaurant comes closest (very close) '
#  "to the best restaurants we frequented in nm. yes, it's a bit pricey, but you "
#  'get what you pay for. service is fabulous....more',
#  ' seafood, american, international hits & misses for this place.  i feel this '
#  'place is overpriced considering the ambiance and food quality.  we were a '
#  'party 4 adults and were placed in one of the booths - it was too tight; and '
#  "if i'm paying upper 20's to upper...more",
#  ' italian, vegetarian friendly, vegan options i went there with some friends '
#  'and their baby around christmas. our server was clearly upset when we told '
#  'him we only wanted some drinks, coffees and a couple desserts (basically, '
#  'not dinner but still, a full order): it took him half an hour to...more',
#  ' american, bar, vegetarian friendly we had to wait a few minutes to get it '
#  'but it was well worth it. i would rate the salsa...the best ever and it came '
#  'with a basket of fresh chips for only $3!!! the fries also i would say the '
#  'best i have...more',
#  ' steakhouse, italian, bar we come to brio once a month. they are good food '
#  'at a very reasonable price. their selection of wine is great for a chain '
#  'restaurant. we really like their attention to kids (ask for the pizza dough '
#  'for them to play with and make...more',
#  ' american, vegan options, gluten free options stopped in yesterday for '
#  'breakfast. when in jersey i will always go for taylor ham for breakfast. i '
#  'ordered eggs benedict and asked for taylor ham for the meat. when you cook '
#  'taylor ham it is sliced very thin and i received my eggs benedict...more',
#  ' italian, vegetarian friendly, vegan options first time for dinner. 2 '
#  'couples. delicious mushroom soup and scallop and salad appetizers. fish main '
#  'dishes from the creative menu side prepared in a potato crust were super. '
#  'short ribs excellent. daily special tortellini stuffed with meat was '
#  'outstanding. terrific service and frequent checking...more']

# %%
def clean_text(text):
    # Lowercasing
    text = text.lower()

    # Penghapusan Mention
    text = re.sub(r'@[A-Za-z0-9]+', '', text)

    # Penghapusan Hashtag
    text = re.sub(r'#', '', text)

    # Penghapusan Emoji
    text = demoji.replace(text, "")

    # Penghapusan Karakter Newline
    text = text.replace('\n', ' ')

    # Penghapusan Angka
    text = re.sub(r'\d+', '', text)

    # Penghapusan White Space Tambahan
    text = re.sub(r'\s+', ' ', text)

    # Pembersihan Teks Tambahan
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenisasi
    tokens = word_tokenize(text)

    # Pembersihan Teks
    tokens = [word for word in tokens if word.isalnum()]

    # Penghapusan Stopword
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if not word in stop_words]

    # # Stemming
    # stemmer = PorterStemmer()
    # tokens = [stemmer.stem(word) for word in tokens]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return ' '.join(tokens)

def cleaner(data):
    data['text_preprocessed'] = data['description'].apply(clean_text)
    return data

# %%
cleaner(df_clean)
df_clean.head()
# Out:
#                                    name       street_address  \
# 1                     coach house diner        55 state rt 4
# 2                      table talk diner  2521 south rd ste c
# 3                           sixty vines     3701 dallas pkwy
# 4                          the clam bar    3914 brewerton rd
# 6  black angus steakhouse - federal way      2400 s 320th st
#
#                                        type  reviews  no_of_reviews  \
# 1      diner, american, vegetarian friendly      4.0             84
# 2      american, diner, vegetarian friendly      4.0            256
# 3   american, wine bar, vegetarian friendly      4.5            235
# 4                    american, bar, seafood      4.0            285
# 6                 american, steakhouse, bar      4.0            220
#
#                                             comments  price_range     type1  \
# 1  both times we were there very late, after 11 p...          2.0     diner
# 2  waitress was very friendly but a little pricey...          2.0  american
# 3  not sure why i went there for the second time....          2.0  american
# 4  doesn't look like much from the outside but wa...          2.0  american
# 6  this is an easy any time place to have dinner!...          2.0  american
#
#         type2                type3          city state  \
# 1    american  vegetarian friendly    hackensack    nj
# 2       diner  vegetarian friendly  poughkeepsie    ny
# 3    wine bar  vegetarian friendly         plano    tx
# 4         bar              seafood      syracuse    ny
# 6  steakhouse                  bar   federal way    wa
#
#                                          description  weighted_ratings  \
# 1   diner, american, vegetarian friendly both tim...             336.0
# 2   american, diner, vegetarian friendly waitress...            1024.0
# 3   american, wine bar, vegetarian friendly not s...            1057.5
# 4   american, bar, seafood doesn't look like much...            1140.0
# 6   american, steakhouse, bar this is an easy any...             880.0
#
#                                    text_preprocessed
# 1  diner american vegetarian friendly time late p...
# 2  american diner vegetarian friendly waitress fr...
# 3  american wine bar vegetarian friendly sure wen...
# 4  american bar seafood doesnt look like much out...
# 6  american steakhouse bar easy time place dinner...

# %%
pprint(df_clean['text_preprocessed'].to_list())
# Out:
# ['diner american vegetarian friendly time late pm time many diner forget '
#  'restaurant get warmedover food lousy service food uniformly good service '
#  'quite good werent many people itmore',
#  'american diner vegetarian friendly waitress friendly little pricey diner '
#  'food delicious menu wide variety food choose choice would good one',
#  'american wine bar vegetarian friendly sure went second time go terrible '
#  'average place need food clean menu filthythe table filthy impossible amore',
#  'american bar seafood doesnt look like much outside walk either front door '
#  'back door get greeted sat almost immediately waitress amazing helpful large '
#  'variety offer wife satisfiedmore',
#  'american steakhouse bar easy time place dinner week night special occasion '
#  'food reasonably priced always delicious',
#  'mediterranean greek healthy husband went greece last fall fell love beauty '
#  'food dallas business trip came across zizikis thought wed give go knowing '
#  'risky weeksmore',
#  'italian pizza vegetarian friendly love vinces pizza neighborhood meeting '
#  'small pizza salad delicious would expect service friendly attentive delivery '
#  'quick one expect amore',
#  'american steakhouse gluten free option ambience food service excellent '
#  'student cornell look forward dinner',
#  'italian vegetarian friendly gluten free option nice big dining area hold '
#  'many people never feel crowded food cocktail really good',
#  'cafe american vegetarian friendly place youre combo excellent sincerely '
#  'unpretentious im usually breakfast lover ill back try corned beef potato '
#  'treat',
#  'irish bar pub time disappointing beer variety selection always good food '
#  'wasnt worth price fish meet portion general small close welldone service '
#  'personal wasnt committed finished dinner plate weremore',
#  'american bar vegetarian friendly came group eight people wonderful evening '
#  'food wide variety high quality service excellent flatbread deluxe hamburger '
#  'unique burger extremely tasty spicy grilled green bean appetizer platter '
#  'outstandingmore',
#  'american cafe healthy first time part montclair since arrived pm never '
#  'ending influx customer good hour busy restaurant rushed fully enjoyed food '
#  'enjoying ourmore',
#  'american bar pub brought family dinner saturday busy staff attentive food '
#  'take long tiger tot amazing rest food good well little noisy andmore',
#  'chinese asian taiwanese din tai fung always inconstantly great dumpling '
#  'noodle rice dish sublime service fast friendly everything great fresh make '
#  'sure forget vegetable green work ofmore',
#  'belgian french cafe food service good size portion relative price little '
#  'disappointing nicely accommodate large family gathering nice poutine '
#  'outstandingmore',
#  'steakhouse mexican vegetarian friendly food always great margarita best wait '
#  'staff always courteous friendly best texmex town',
#  'american vegetarian friendly vegan option dined lunch group four ordered '
#  'course offering excellent value quality exceptional food fresh hot '
#  'adequately portionedno disappointment better foodwhich hard dowas attentive '
#  'pleasant server eden trulymore',
#  'bar contemporary fusion took fiancé valentine day discovered back gluten '
#  'allergy really limited eat hand skeptical long story short food delicious '
#  'left verymore',
#  'american european vegetarian friendly one favorite brunch place seattle came '
#  'back second time town food absolutely lovely baked potato bit dry taste '
#  'overall great place brunch',
#  'italian vegetarian friendly gluten free option bv tuscany great location '
#  'shop local movie theater always find street parking close food delicious '
#  'fresh excellent quality service always point friendly romantic inside '
#  'dessert aremore',
#  'latin spanish vegetarian friendly place horrible dont know treat customer '
#  'especially fault place ran idiot owner ashamed representing loyal customer '
#  'year aftermore',
#  'american bar gastropub went recently saturday night birthday celebration '
#  'like atmosphere loud didnt mind menu eclectic appealing problem everything '
#  'left little bit desired mainly enough themore',
#  'italian vegetarian friendly gluten free option live part time italy tough '
#  'critic many italian restaurant u paradise surprised u two excellent dish '
#  'would good italy pasta cream sauce sausage super rich creamymore',
#  'spanish mediterranean wine bar unique tapa menu mexican restaurant waiter '
#  'made excellent recommendation course small portion tapa made ideal try '
#  'several everything ordered delish classy relaxing ambiance',
#  'chinese asian vegetarian friendly cant tell enough amazing food edamam '
#  'ravioli die one dish didnt like favorite part visiting atlantic city',
#  'mexican southwestern vegetarian friendly decent service nothing write home '
#  'got fajitas meat way seasoned beef super chewy tortilla good thing meal '
#  'sister got stuffed avocado meal good itmore',
#  'mediterranean greek italian great staff super atmosphere superb staff like '
#  'greek food place must compared restaurant star actually overcrowded well '
#  'worth visit',
#  'italian vegetarian friendly vegan option fabulous deserves michelin star '
#  'already course dinner wintry sunday night course marvelous said linguine '
#  'geoduck favorite followed closely vealtunasweetbread appetizer pork '
#  'agnolotti branzinomore',
#  'american bar pub tuesday moore burger burger good large service however good '
#  'wife ordered bacon burger get mentioned waitress wouldnt chargedmore',
#  'american steakhouse gluten free option nice evening professional kind '
#  'service cozy atmosphere everything delicious shared oyster truffle fry '
#  'asparagus beautiful steak would go monthly lived',
#  'italian pizza vegetarian friendly six u dined last night carbonara pizza '
#  'gnocchi caprese dessert excellent taste presentation warm friendly attentive '
#  'service love place new favorite seattle',
#  'caribbean latin spanish came high hope left underwhelmed hoping something '
#  'bit different interesting waitress spent time describing drink food made '
#  'realise bar restaurant food wasmore',
#  'american cafe diner great home style food yummy breakfast large portion '
#  'tried chicken strip burger chicken fried steak pie great',
#  'american southwestern vegetarian friendly fantastic experience bartender '
#  'knowledgeable menu joy talk server joe knowledgeable attentive food devine '
#  'appetizer world elk main course andmore',
#  'indian asian vegetarian friendly thoroughly enjoyed valentine weekend dinner '
#  'wed advised friend arrive early weekend arrived opened dinner service dont '
#  'accept weekend reservation pm line ofmore',
#  'american bar international frisco stop drink amazing service great food '
#  'great',
#  'american bar seafood sure enjoyed meal margarita buzzard billy place hard '
#  'get construction well worth river great view nice indoors friendly staff',
#  'american seafood vegetarian friendly course menu available anytime january '
#  'good deal salmon dip northwest duet good however salmon dip accompanied '
#  'couple cracker slice apple hot fudge sundae formore',
#  'asian thai vegetarian friendly meeting federal way going end late knew '
#  'needed get lunch right away researched place sounded good glad went kwan tip '
#  'wing wasmore',
#  'greek italian pizza place run family since opened salad half meatball '
#  'grinder sliced meatball tomato sauce cheese thing delicious messy eat '
#  'imagine roundmore',
#  'american seafood bar excited go early valentine day dinner thursday day '
#  'holiday see thing changed new owner sat lounge waited table atmosphere '
#  'relaxed themore',
#  'american seafood gluten free option three star restaurant open year '
#  'byobclassy elegant dining wine glass table cloth there one thing fine menu '
#  'would try great chef got hooked',
#  'american steakhouse vegetarian friendly service great steak awesome highly '
#  'recommend capital grill nyc everyone accomodating',
#  'american bar seafood nailed cajun atmosphere felt like could dining new '
#  'orleans restaurant waitress bubbly attentive informative ordered oyster '
#  'different north eastern state oyster gulf never knew theymore',
#  'american vegetarian friendly vegan option lot bread butter start expensive '
#  'small drink much ice matter ask big bowl cheap lettuce minimal nothing '
#  'special ingredient slice calorie cheesecake lol argh stay away pleasemore',
#  'american steakhouse gluten free option tremendous service nice atmosphere '
#  'ordered large filet mignon lot grisly fat middle didnt complain cause im one '
#  'time steak well average prefermore',
#  'american vegetarian friendly vegan option ordered location ill say excellent '
#  'burger good size tasty pricey',
#  'japanese sushi asian mt st helen special roll avocado crab meat inside fish '
#  'variety outside great creative sushi good soba noodle mediocre dont go '
#  'formore',
#  'asian thai vegetarian friendly recently received score health department '
#  'score higher closing establishment dont think ill back',
#  'thai asian vegan option extensive menu disappoint goto place thai food near '
#  'home love tom yum tom ka soup often order soup side rice excellent meal',
#  'italian american pizza even boy brooklyn ny enjoyed pizza nice soft pizza '
#  'good cheese mushroom pepperoni also bison burger cooked way like staff '
#  'extremely helpful attentive carried everything wasmore',
#  'american southwestern bar valentine dinner wife grilled ruby red trout said '
#  'excellent crispy fried red fish excellent waiter personable excellent '
#  'service',
#  'italian american seafood say austin visit la volpe first time around far '
#  'already love idea restaurant mom around told incrediblemore',
#  'asian indian tibetan group limited knowledge restaruant fare server ani '
#  'helpful suggesting item made dining experience enjoyable enjoyed panner '
#  'momos spinach naan vegetable thukpa mango chicken lamb saag restaurantcom '
#  'couponmore',
#  'american steakhouse southwestern first time visiting restaurant oh '
#  'phenomenal walking door walking full stomach service food atmosphere price '
#  'disappointed mean',
#  'american wine bar vegetarian friendly food good priced opinion extremely '
#  'good big selection choose waitress extremely good beginning tended ignore u '
#  'end place crowded people standingmore',
#  'latin cuban caribbean visted sat nightbusy make sure reserve tablemoderately '
#  'pricedexcellent portionsstarted beef empanadastasty greasy allalso cuban '
#  'chorizocould spicierbut excellentfor entree stuffed porkchop chorizo '
#  'manchego cheesesmothered pear onionsalsomore',
#  'italian pizza vegetarian friendly heard pane e vino friend decided try met '
#  'owner escorted table three u ordered lasagna thought really good fourth '
#  'person ordered veal picatta andmore',
#  'american vegetarian friendly gluten free option sister came christmas eve '
#  'dinner could pleasant melt mouth salmon expertly prepared loved also '
#  'delightful cheesecake wonderful coffee dessertmore',
#  'american seafood gluten free option restaurant feel like walking past good '
#  'way greeted gentleman polite organized waiter never stopped moving polite '
#  'good request even makemore',
#  'indonesian american vegetarian friendly weve nice classy place dinner '
#  'husband remain satisfied four corse menu every plate delicious service '
#  'awesome chief attentive every guest recommended',
#  'american steakhouse gluten free option celebrating end reserved yet table '
#  'set fourawkward lot young family small child fun watch gorgeous smart sweet '
#  'wife modern caesar salad come two piece petite garlic toastsmore',
#  'italian vegetarian friendly vegan option sister husband went mom th birthday '
#  'wonderful restaurant food service spectacular portion surprisingly large '
#  'course pay get brotherinlaw picked tab tomore',
#  'italian pizza fast food black friday everything else crowded decided grab '
#  'quick bite line moved fast good cheese pizza good veggie averagethe '
#  'spaghetti okay',
#  'latin barbecue brazilian food drink always point visit time month today '
#  'guest singer aweful singssounds terrible loud chase customer away band '
#  'played brasilia febmore',
#  'american bar pub stopped looked cozy real wood burning fireplace menu unique '
#  'item many beer choose waiter dave suggested beer exactly husband liked asked '
#  'imore',
#  'american sushi gluten free option metropolitan cafe dependable always fresh '
#  'delicious food went recently brunch delicious large variety option great bar '
#  'take reservationswhich isnt common brunch area',
#  'american barbecue gluten free option went walking distance hotel everything '
#  'la carte dry meaning lean brisket coleslaw husband bean given baggie slice '
#  'white bread cafeteria stylemore',
#  'american bar vegetarian friendly staff attentive gave good wine '
#  'recommendation good service salmon delicious ate every bite trouble dealing '
#  'gluten free food option unusually wouldmore',
#  'japanese sushi asian pleasantly surprised quality food ambiance '
#  'establishment felt japanesewill back',
#  'italian pizza vegan option typical americanitalian eatery cuisine really '
#  'american idea italian food like rather authentic italian find dish pretty '
#  'blah although appreciate use flavorful cheesemore',
#  'japanese sushi asian love oto sushi go least week recall ever getting meal '
#  'thoroughly enjoy menu full elegant delicious choice price great service '
#  'immaculate helpful notmore',
#  'mexican latin spanish food everything terrible tortilla soup wonderful '
#  'fajitas recently also offer indian food odd best thing menu coronarita stick '
#  'chip salsa',
#  'american cafe vegetarian friendly welcoming trendy setting creative twist '
#  'even basic dish great meal great atmosphereand owner staff couldnt cordial '
#  'every item beautifully presented flavorful stop latte full meal wontmore',
#  'italian vegetarian friendly vegan option daughter nefew great food great '
#  'service great price home cooked meal friendly waiter small quaint atmosphere',
#  'american vegetarian friendly vegan option found bob right next door hotel '
#  'convenient didnt drive day place fairly busy seated right away opted glass '
#  'water grandson took onmore',
#  'italian pizza vegetarian friendly wanted give feedback regarding last visit '
#  'thurs th birthday went guy favorite restaurant however disappointed service '
#  'night probablymore',
#  'asian vietnamese vegetarian friendly restaurant nice place good food serving '
#  'food huge tasty service quick restaurant clean place worth money',
#  'italian vegetarian friendly vegan option husband town night run katy half '
#  'marathon next morning familiar area wanting carb load looked nearby italian '
#  'restaurant pleasantly surprised find gem hadmore',
#  'mexican latin bar lovely food got pushed special turned original order '
#  'little annoying tiny piece salmon shrimp one scallop fingerling potato worth '
#  'everything else tastymore',
#  'french international european four u dinner u ordered seafood ravioli like '
#  'little ethereal pillow good also seared foie toast point excellent crab cake '
#  'huge bit bland someone else duck withmore',
#  'mediterranean middle eastern vegan option area holiday visited today dinner '
#  'food fantastic staff lovely patient explaining worked would definitely '
#  'recommend',
#  'american bar cafe place wonderful tried first time late summer couple time '
#  'friendly staff great atmosphere feel like left pacific northwest bit food '
#  'excellent went specificallymore',
#  'italian pizza vegetarian friendly really dont enjoy italian place since '
#  'gluten free accommodating gluten free penne pasta pasta meal gluten free '
#  'pizza crust knowledgable employee settled soup salad rest ofmore',
#  'seafood european spanish place like tardis restaurant walk nice little bar '
#  'continue dining room altogether must hold people good tapa great grilled '
#  'octopus full menu aboutmore',
#  'american seafood vegetarian friendly one restaurant high list moved area '
#  'hadnt gotten tonight read recent pretty favorable review time union multiple '
#  'change ownership chef didnt phasemore',
#  'american international vegetarian friendly pjs many time person delivery '
#  'food always fresh tasty flavorful breakfast item well cheese steak great '
#  'lunch would highly recommend',
#  'american greek diner recently rainbow diner dinner many time food week '
#  'exceptionally good food delicious served nice hot ordered seafood dish '
#  'cooked perfectly bread pudding wasmore',
#  'american bar pub cool place lot craft beer tap full bat limited food good '
#  'staff awesome cozy funky little place',
#  'german european vegetarian friendly food pretty good unbelievably loud felt '
#  'like cafeteria people screaming one another made hard conversation kind '
#  'ruined meal acoustic could fixed',
#  'american steakhouse gluten free option rd time brunch always recommend '
#  'amazing food great customer service pleasure jacob server made dining '
#  'experience outstanding highly recommend',
#  'mediterranean greek vegetarian friendly place great food got food quickly '
#  'staff friendly atmosphere casual feel rushed plus water taste good',
#  'italian vegetarian friendly gluten free option long weekend decided go '
#  'restaurant relaxing quiet lunch food good different appetizer service little '
#  'overwhelmed overall goood restaurant',
#  'italian pizza vegetarian friendly good pizza great wing fried calamari use '
#  'semolina always burn bottom pizza otherwise pretty good pie',
#  'french gluten free option vegetarian friendly one favorite restaurant '
#  'kirkland great view carillon marina lake washington always excellent service '
#  'love french onion soup',
#  'french vegetarian friendly vegan option wonderful restaurant pleasant menu '
#  'daniel french culinary heritage food amazing',
#  'italian pizza vegetarian friendly pizza okay nothing special heard try place '
#  'pizza amazing im still convinced ordered large pizza takeout cost almost '
#  'dough bordering onmore',
#  'american seafood vegetarian friendly go lobster shop every year valentine '
#  'never disappoints make sure book advance taste menu perfect service even '
#  'better',
#  'american bar gluten free option prepared new year eve rush reservation '
#  'waited minute asking hold complained sat u took minute food arrived brought '
#  'appetizer main course timemore',
#  'italian vegetarian friendly vegan option novellis really nice classy '
#  'restaurant stepped foot owner sweet greeted u well sat nice table fireplace '
#  'waiter great food best part trulymore',
#  'mexican latin vegetarian friendly many choice mexican food border decided '
#  'try something new glad tried andale live music night minute wait table '
#  'wemore',
#  'japanese barbecue sushi covenant group get together month outing andor '
#  'dinner yesterday went escape room located fm spring dinner qshi bbq bistro '
#  'reservation qshi elected sit themore',
#  'french gluten free option vegetarian friendly enjoyed amazing business lunch '
#  'lobster bisque crusted sea bass pecan bread pudding food fantastic service '
#  'expectation',
#  'american deli vegetarian friendly fabulous lunch spot sandwich awesome came '
#  'day row visiting michigan talked daughter said dont like reuben taste mine '
#  'today three u eatingmore',
#  'irish bar pub place reminded irish pub visited dublin reuben world loaded '
#  'meat rye perfect thing lacking dill pickle',
#  'chinese asian seafood would give could came recent sunday dim sum parked '
#  'street knowing small parking lot next restaurant restaurant lot full walked '
#  'arrivedmore',
#  'american bar pub absolutely love fry great seasoning cooked right good salad '
#  'burger worth visit',
#  'american steakhouse vegetarian friendly like many capital grille winner '
#  'great food even better service really care special wish also like wine pad '
#  'information wine',
#  'irish bar pub colby ave lot restaurant including irishman best advice '
#  'consider good place beer skip food keep walking one many restaurant colby '
#  'wife met another couplemore',
#  'american bar vegetarian friendly signed valentine day special menu dinner '
#  'previous year wonderful last month noticed several dinner lunch problem '
#  'quality food unpredictable never enough staffvery slow service wellmore',
#  'mediterranean greek vegetarian friendly experienced terrible service place '
#  'came sunday lunch family taken table one ever came service waiter gathered '
#  'together watching soccer game cell phone amore',
#  'steakhouse american seafood u went try dee lincoln primr good steak better '
#  'char broiler oyster appetizer terrible fishy strong odor great service '
#  'expensive also include something steak',
#  'american bar pub food really good portion great plenty tv watch lot sport '
#  'time get loud thats sport bar right best thing place thatmore',
#  'mexican latin central american place must taco fan think best place satisfy '
#  'mexican craving worth wait please tastebud back price wise think great '
#  'valuemore',
#  'american vegetarian friendly vegan option great place decor classy '
#  'comfortable vibe intimate waiter rick extremely friendly knowledgeable menu '
#  'made excellent suggestion also paced meal well attentive without intrusive '
#  'andmore',
#  'asian thai sushi take local asian restaurant perfect small hole wall '
#  'location mongolian beef amazing con gave spice level option said five three '
#  'time waitress correctedmore',
#  'american cafe vegetarian friendly tomato bisque amazing good service nice '
#  'location overlooking boardwalk beach good hamburger outrageously priced '
#  'would definitely back',
#  'american bar pub wait staff marveloushowever dinner left lot desiredfood '
#  'apparently piled platedinner none extra salad roll say place would return',
#  'gastropub american bar tremendous amount drink beer selection food smaller '
#  'menu ordered pork beef taco delicious smoked pepper distinct smoky flavor '
#  'slow spice hotness somewhat roadhouse scene',
#  'american bar pub eaten pearl handful time last night really outstandingthe '
#  'mixed cocktail start freshest oyster weve long long time small plate '
#  'delicious octopus mushroom shrimp filetmore',
#  'american bar seafood drive poughkeepsie decided river station usually go '
#  'warm weather sit outside love chowder figured wed give winter try turned '
#  'tomore',
#  'italian american bar around whole pie topping get different pie order slice '
#  'prefer pizza huge inch decent drink choice nice touch cucumber water',
#  'seafood vegetarian friendly vegan option met daughter boyfriend brunch '
#  'reserved window seat beautiful view water rare sunny day service great food',
#  'italian pizza fast food good pizza good burger good price stay next mike '
#  'pizza perfect place next u',
#  'american cafe vegetarian friendly upon reading review please dont tell '
#  'anybody secret ocean city gem cheer breakfast lunch oc egg salad scrapple '
#  'turkey special creamed chipped beef cheesesteaks always quality food served '
#  'personality see youmore',
#  'american asian fast food restaurant burned july still boarded security fence '
#  'way around closed month imagine business closed long start backmore',
#  'american seafood cajun creole nothing made birthday special spending people '
#  'love cherish mosti love restaurantthey never disappointed methe food superb '
#  'best customer service around',
#  'american diner vegetarian friendly triangle diner place go breakfast '
#  'anywhere near saratoga spring ny serving plentiful menu diverse food simply '
#  'delicious french toast pancake biscuit sausage gravy corned beef hashmore',
#  'american bar pub looking great culinary experience group friend decided '
#  'venture well really beer drinker fan seared animal flesh side anything '
#  'willmore',
#  'american vegetarian friendly vegan option husband absolutely love food '
#  'atmosphere staff food hand best ever highly recommend',
#  'italian pizza gluten free option bread always best prosciutto flatbread '
#  'savory mouth watered special day verde trio scallop shrimp crab meat white '
#  'wine sauce delicious justmore',
#  'indian pakistani vegetarian friendly grilled lamb came potato chicken '
#  'biryani came basmati rice potato flavorful basmati rice curry meat flavorful '
#  'higher price justified bigger portion one thingmore',
#  'american steakhouse gluten free option john howie steak outstanding '
#  'outstanding virtually every way said also expensive special occasion worth '
#  'restaurant add automatic service charge entire bill shared staff thatmore',
#  'seafood european spanish spanishbasque restaurant ironbound district ferry '
#  'street may make destination local get speak spanish men born galicia eating '
#  'bar entree come thickmore',
#  'chinese sushi asian first time lunch anxious find difference lunch dinner '
#  'menu standard cooked item pretty similar sushi seafood selection selection '
#  'lot le lunch peking duck wrap themore',
#  'american bar diner hot mess fantastic great waitstaff good breakfast vibe tv '
#  'meme hysterical',
#  'mediterranean vegetarian friendly vegan option dinner friend show four u '
#  'ordered different entree u delighted choice waiter pleasant knowledgeable '
#  'enjoyable experience back',
#  'american vegetarian friendly gluten free option wife celebrated th wedding '
#  'anniversary family rd time time amazed good service food especially steak '
#  'asada enchilladas',
#  'american steakhouse bar awesome customer service great steak always good '
#  'location business meeting must try',
#  'bar american pub grilled chicken fabulous sweet potato course cant skip '
#  'bread side salad salad crisp cold way bread warm delicious always downfall '
#  'chicken moist andmore',
#  'american bar vegetarian friendly hostness greeted u wonderful smile server '
#  'alyssa friendly efficent food always delicious restroom clean',
#  'irish bar pub traditional bar singing dollar bill wall fun staff great drink '
#  'fish chip shepherd pie suggestion',
#  'barbecue american southwestern went evening nd january late enough '
#  'somethings good got venison sausage pulled pork smoked turkey brisket meat '
#  'tasty wemore',
#  'american italian vegetarian friendly nice place go meal great happy hour '
#  'wonderful server nice atmosphere food tasty love come back try',
#  'american fast food diner white manna around since serving award winning '
#  'slider mini burger eaten two three bite whats even fun building hold around '
#  'fifteen customer unheardmore',
#  'chinese asian vegetarian friendly love asian dumpling place disappoint '
#  'located back asian inspired mall main street made adventure finding '
#  'restaurant decorated welcoming oriental motif romantic first date subsequent '
#  'date night themore',
#  'italian european sicilian little restaurant provide amazing food nicest '
#  'people meet loved would happily come ny',
#  'italian spanish vegetarian friendly stayed overnight kennewick discovered '
#  'accident great bistro run father son food great restaurant small enough '
#  'doesnt get noisy wine glass little pricey side wonderful wemore',
#  'american international vegetarian friendly lunch selection preparation good '
#  'fried egg blt quite tasty companion chicken sammy liked ti much wife side '
#  'grilled broccolini excellent andmore',
#  'european vegetarian friendly gluten free option food delicious atmosphere '
#  'appealing thoroughly enjoyed dinner salis bistro definitely back',
#  'american diner gluten free option spokane must go place set historical '
#  'railroad dining car place small great food primarily specializing breakfast '
#  'variety item menu wife burger friesmore',
#  'asian thai vegetarian friendly found little gem new york find food fantastic '
#  'service amazing friend lunch special enough food favorite green thai curry '
#  'absolutely loved itmore',
#  'steakhouse latin argentinean always enjoy eating asado wife favorite '
#  'cheapbut mostly worth dont understand service charge tho',
#  'american bar vegetarian friendly make sure reservation showed appointed time '
#  'people waiting table basically sat right look even though monday night place '
#  'packed loudthemore',
#  'mexican american southwestern place austin manchaca good better salt lick '
#  'line long time nearly long franklin reasonably priced give plenty eat '
#  'favorite bbq town',
#  'italian pizza neapolitan family become snobby come pizza chain store dont '
#  'cut pizza win award loved sauce topping fresh crust perfect spectacular',
#  'mexican southwestern vegetarian friendly came lunch rush ended immediately '
#  'seated took awhile figure order lot unique taco option including oxtail '
#  'quite happy choice blackened fish taco three came plate withmore',
#  'american steakhouse bar arrived minute early rude hostess table ready made u '
#  'seat cold lobby requested seated wait rest party ignored guest speaking '
#  'fellow employee good food though',
#  'italian pizza vegetarian friendly looking great pizza amazing saladsand '
#  'great service need try done great service',
#  'italian pizza vegetarian friendly good food excellent service arrived early '
#  'dinner errand within hour must people waiting every table full family five '
#  'shared caesar salad meat lover pizza shrimp pasta andmore',
#  'italian pizza vegetarian friendly matter introduce nick pizza always want go '
#  'back excellent salad calzones favorite pizza fh thin crust fresh mozzarella '
#  'excellent sauce great option topping toomore',
#  'italian pizza vegetarian friendly regular place eat lubbock today found new '
#  'regular place place incredible calzone amazing usually calzone guy since '
#  'splitting pizza decided heck imore',
#  'american seafood bar house wine really good wine fried pickle best lightly '
#  'breaded greasy bowl crab chowder excellent husband stuffed flounder special '
#  'gorgeousmore',
#  'american gastropub pub quiet night recent big snow good bartender stayed top '
#  'everything friendly small crowd nice wine glass burger roast pork sandwich '
#  'prepared order good ill return people commentmore',
#  'american bar cafe great brunch spot around long time right next cornell '
#  'university try making reservation prepared wait weekend brunch good espresso '
#  'upstairs wait good bloody mary well',
#  'american bar vegetarian friendly celebration grandkids great time exploring '
#  'restaurant grandkids food good',
#  'american vegan option vegetarian friendly absolutely love shopping wegmans '
#  'cherry hill mount laurel great product great quality vast selection '
#  'reasonable price staff friendly helpful knowledgeable store stock product '
#  'time spend hour browsing andmore',
#  'caribbean latin spanish quite time mediocre buffet liquor licence also '
#  'remodeled wonder ownership changed give separate check either red sangria '
#  'musicmore',
#  'mexican latin vegetarian friendly love place food fantastic service great '
#  'server nicknamed coco introduced u menu made u aware famous dish molcajete '
#  'churrasco carne asada grilled chicken pork chop mexican sausage grilled '
#  'shrimp served amore',
#  'seafood italian vegetarian friendly loved food caffe aldo walked restaurant '
#  'beautiful presentation plate gorgeous especially liked crab cake appetizer '
#  'calamari appetizer light airy zucchini fry weremore',
#  'american seafood gluten free option salad steak shouldve stopped shared '
#  'large order mussel time id savored share mussel sopped accompanying sauce '
#  'sauce supplied bread really didnt roommore',
#  'bar american vegetarian friendly past dining experience bi main always '
#  'positive ive always raved friend colleague mine however last experience '
#  'holiday changed mind older gentleman host owner checked u shouldmore',
#  'japanese sushi asian number time never disappointed food excellent service '
#  'excellent spicy cocktail excellent experience like sushi restaurant houston',
#  'mexican southwestern latin eaten kikis time never get tired delicious plate '
#  'favorite taco mole good got ta try salsa dish',
#  'american vegetarian friendly vegan option ok see earlier review good place '
#  'overall drove hour get ludricrous wing eaten ghost pep scotch bonnet name '
#  'andi really looking forward testingmore',
#  'american bar vegetarian friendly go dessert coffee however self proclaimed '
#  'foodie foodie paradise meal prepared quality product however meal took hour '
#  'receive cold finally received meal recommendation go bomb dessert',
#  'american seafood cajun creole group u get foodwaiter tried hard either '
#  'kitchen screwed much took forever two table came u left u',
#  'chinese asian vegetarian friendly friend recommended place u lunch popular '
#  'think good sign price reasonable brought pot tea glass water next came egg '
#  'drop soup ordered stringmore',
#  'chinese asian vegetarian friendly think worse service saw food isnt good '
#  'order peking duck one expensive dish place worse one tried life would say '
#  'pekingmore',
#  'american seafood vegetarian friendly great place quick lunch friend place go '
#  'town visitor enjoy visit',
#  'american cafe deli terrific sandwich everything fresh homemade nothing jar '
#  'friendly staff interesting decor im glad ventured fall try really worth stop',
#  'american steakhouse bar nothing special visiting town review search local '
#  'restaurant burger good service lousy made open table reservation non busy '
#  'time expected much better service non attentive server couldnt even remember '
#  'orderedmore',
#  'seafood mexican latin went large group meeting service good clean facility '
#  'food smaller portion somewhat pricey expected however dish tried unique '
#  'tasty waiter provided good recommendationmore',
#  'italian vegetarian friendly vegan option warn welcoming environment '
#  'excellent customer service food delicious authenticif enjoy great italian '
#  'food wonderful hospitality place',
#  'italian pizza vegetarian friendly great food excellent service two level '
#  'restaurant pizzeria parking back easy get highway',
#  'italian vegetarian friendly vegan option came saturday night girlfriend '
#  'another couple must say food great atmosphere amazing waiter nick nice '
#  'helpful question menu highlymore',
#  'american bar vegetarian friendly meal outstanding menu vast fairly priced '
#  'portion large well waitress amazing genuine quick wonderfully polite superb '
#  'meal cant wait come back pro tipifmore',
#  'american bar vegetarian friendly new assistant manager kevin helpful needed '
#  'assistance friend car parking lot came stood cold u helped u going made sure '
#  'okay beforemore',
#  'asian mongolian chinese food great service even better like place lot want '
#  'go back next day need hour waiting time since cold night bad cant another '
#  'good one ismore',
#  'american vegetarian friendly vegan option couldnt believe scope menu finally '
#  'settled fried chicken waffle fantastic menu robust cant find meal youre hard '
#  'please',
#  'asian thai vegetarian friendly thai noodle soup fantastic date green curry '
#  'also delicious service spot',
#  'pub american brew pub convenient location delicious food great service erdem '
#  'stayed marriott convenient food great breakfast dinner',
#  'italian vegetarian friendly vegan option lot thing going convention center '
#  'difficult find place eat place recommended people tangier shopping center im '
#  'glad encouraged group go restaurant lotmore',
#  'american bar vegetarian friendly group three driving home baltimore north '
#  'jersey looking late lunch spot pulled farm fisherman tavern ta decided give '
#  'try got pm andmore',
#  'american bar vegetarian friendly ate several day week food service '
#  'consistently excellent big portion size friendly waiting bar staff quick '
#  'service reasonable price honest waiting staff waitress chased u door tell u '
#  'amore',
#  'mexican vegan option vegetarian friendly visited laredo work vegetarian '
#  'place serf vegetarian meal visited place lunch expecting much food '
#  'presentation surprised really innovative presentation andmore',
#  'greek american vegetarian friendly wow one best burger world variety food '
#  'chose menu plus shake die',
#  'italian vegetarian friendly vegan option excellent food service meatball '
#  'appetizer favorite steak excellent large wine selection chicken parmigiana '
#  'spaghetti garlic oil recommended',
#  'seafood vegetarian friendly gluten free option went pappadeaux seafood '
#  'kitchen pharr excellent review nice server could tell new one entree come '
#  'reminded still get told tomore',
#  'mexican southwestern vegetarian friendly yummy new area tried three taco '
#  'share good although hubby wasnt impressed shrimp taco breakfast taco '
#  'delicious',
#  'bar italian american casual meeting place good mixed drink menu nice '
#  'selection entree appetizer wife vegetarian found option always nice make '
#  'great manhattan',
#  'french european vegetarian friendly etoile one favorite restaurant valentine '
#  'day huge disappointment looking forward enjoying champage husband made '
#  'reservation week ahead time even securing credit card arrivedmore',
#  'steakhouse brazilian gluten free option went dinner wife bellevue location '
#  'lacked organization fogo de chao minneapolis great experience bellevue '
#  'location need help salad bar organized good flow selection waitermore',
#  'french vegetarian friendly vegan option enjoyed lowkey relaxed evening '
#  'interesting interior helped set laidback mood champagne offering glass '
#  'something appreciate champagne flight nice surprise menu offer interesting '
#  'savory soufflé option smoked salmon delicious butmore',
#  'american steakhouse seafood short walk hotel looked lot better shari dennys '
#  'menu large great selection service quick friendly quantity food bit top '
#  'havemore',
#  'american bar vegetarian friendly chance stop check rusty moose flight '
#  'spokane airport sunday lunch rusty moose reminded log cabin cottage life '
#  'country homesmore',
#  'italian pizza vegetarian friendly great visit good cocktail excellent food '
#  'sopresatta pizza wild mushroom pizza incredible kale salad led way evening',
#  'american seafood vegetarian friendly enjoyed dinner total business colleague '
#  'service excellent nice selection wine beautiful steak seafood comfortable '
#  'environment could easily hear conversation across large table quality food '
#  'option',
#  'american bar pub went whim grab drink bite ended staying hour vibe good '
#  'twist menu standard great cant wait go friend',
#  'american steakhouse gluten free option celebrating belated valintines avoid '
#  'crowd enjoy leisurely dinnerwe eaten twice meal inconsistent time everything '
#  'exceptional server attentive intrusive steve jimmie professional '
#  'personablemymore',
#  'mexican vegetarian friendly vegan option service good even gave credit '
#  'kitchen staff tip received customer employer people like food best mexican '
#  'restaurant trio fajitas whichmore',
#  'american cafe vegetarian friendly planned find new place eat breakfast heard '
#  'well long wait list people every standing get decided wait almost hour later '
#  'inmore',
#  'american steakhouse gluten free option given beeper upon arrival one hour '
#  'later checked hostess said called u earlier beeper working weekend asked '
#  'given one wemore',
#  'lebanese middle eastern halal catered work event great meal chicken beef '
#  'lamb huge portion meat prepared perfectly little char tip tender juicy '
#  'inside rice sliver almond beautiful well delicious butmore',
#  'chinese asian vegetarian friendly steamed shrimp dumpling pork shrimp '
#  'potstickers seaweed spicy beef shank dumpling best inexpensive',
#  'italian pizza vegetarian friendly pizzeria grandkids like eat heart little '
#  'italy bronxbeen going pizzeria year',
#  'american vegetarian friendly gluten free option took mom breakfast going '
#  'shopping really like fresh waffle id heard place good one disappointed issue '
#  'figuring get since firstmore',
#  'bar seafood soup okay duke go downtown kent bit yes overpriced typically '
#  'good food service yesterday took wife lunch valentine day order clam '
#  'appetizer couple entree place notmore',
#  'mediterranean greek vegetarian friendly good food right price byob added '
#  'plus reason restaurant tab get expensive wish stayed open later though',
#  'italian vegetarian friendly vegan option great variety food type veal dish '
#  'ive seen elsewhere dont let outside fool much nicer inside',
#  'italian vegetarian friendly vegan option fantastic find capital hill couple '
#  'seattle native wonderful fresh pasta dish important portion make special '
#  'opportunity try great food',
#  'american seafood steakhouse great dinner night super bowl service good food '
#  'tasty venue nice lobster based food february interesting dessert menu good '
#  'wemore',
#  'american asian vegetarian friendly enjoyed evening atmosphere recommend '
#  'dress better jean tennis shoe felt little place service great food hot fresh '
#  'drank three glass iced tea brewed perfection themore',
#  'mexican southwestern vegetarian friendly food restaurant good mexican '
#  'restaurant would thought food would spice food bland restaurant clean staff '
#  'friendly',
#  'caribbean bar bahamian bahama breeze provides wide choice good dish tasty '
#  'cocktail ambiance inviting great music background srevice excellent staff '
#  'always professional friendly',
#  'american international vegetarian friendly fish chicken dish cooked '
#  'perfectly wine sommelier suggested great complement meal definitely place '
#  'celebratory event',
#  'american bar pub always go cabin way skiing vt met friend jersey often '
#  'possible dinner great drink always varied menu keep thing interesting never '
#  'disappointing ill back everymore',
#  'american bar vegetarian friendly hubby lunch absolutely stuffed wasnt casino '
#  'id probably unbutton jean everything delicious waitress phenomenal wish '
#  'remembered name went beyond check jitney schedulesstopsmore',
#  'american bar pub super inventive ingredient many even stumped server good '
#  'craft beer selection food ingredient top notch',
#  'mediterranean middle eastern fast food food really good looking healthy meal '
#  'go place clean team friendly highly recommended',
#  'american diner vegetarian friendly plenty option omelet french toast classic '
#  'egg dish plenty hot coffee service always great feel happy check hour winter '
#  'vary',
#  'mexican southwestern vegetarian friendly frankies restaurant many time year '
#  'taken outoftown guest well result love guest frankies extensive menu item '
#  'always seemore',
#  'mexican southwestern latin tried restaurant first time recent visit see '
#  'daughter houston food good plentiful also enjoyed trying complimentary '
#  'basket variety sweet brought table server pleasant attentive would go back',
#  'mexican southwestern latin quality food always consistent one katy favorite '
#  'mexican food service hit miss time night mostly good want somewhere '
#  'conversation may wantmore',
#  'american irish bar great location atmosphere food overall good onion ring '
#  'amazing staff friendly efficient',
#  'italian pizza vegetarian friendly decided try grimaldis pizzeria since weve '
#  'never coal fired pizza usually wood fired gas rainy tuesday sitting realized '
#  'picked right day since tuesday wine couldntmore',
#  'latin argentinean south american small storefront location busy belt line '
#  'road may take one two pass pull right strip mall make sure big sign flashing '
#  'light small unassuming space whatmore',
#  'american vegetarian friendly vegan option food great sat chef counter able '
#  'watch kitchen staff prepare dishesmade interesting memorable experience',
#  'italian mediterranean vegetarian friendly greatly pleased discovery soho '
#  'staff great food incredible plus good selection wine make pleasant place eat',
#  'american cafe vegetarian friendly cute place nice atmosphere service '
#  'specially great menu pretty hard get table keep waiting mind',
#  'mediterranean greek middle eastern food well presented tasted good like '
#  'spice would return try future',
#  'latin spanish south american wonderful restaurant arepas enjoyed every bite '
#  'service good restaurant small inviting',
#  'american bar seafood visited pacific grill february arrived hour befor '
#  'reservation one couple came u told hostes reservation seated u seated min '
#  'reservationmore',
#  'latin south american vegetarian friendly excellent buffet lot food good '
#  'price lamb beef pork blood sausage chicken done perfectly various seafood '
#  'preparation plenty different salad dessert highly recommend place back many '
#  'time server helpful quick andmore',
#  'american cafe vegetarian friendly delicious egg cheese bagel good price also '
#  'try brownie worth sure',
#  'american vegetarian friendly gluten free option booked restaurant week '
#  'whilst nyc got expensive taxi midtown visit disappointed find despite saying '
#  'clearly online restaurant week music charge monday told even gettingmore',
#  'african ethiopian vegetarian friendly restaurant one favorite visited food '
#  'beyond delicious fell love ethiopian cuisine place clean authentic relaxing '
#  'environment service great become big space canmore',
#  'indian vegetarian friendly vegan option got chicken vindaloo lamb rogan josh '
#  'okra okra fabulous chicken good zesty crazy spicy lamb good quirky '
#  'aftertaste overall good experience',
#  'american bar pub im beer fan way probably order beer time year sitting bar '
#  'bartender explain difference pilsner ale go making beer walkedmore',
#  'american deli vegetarian friendly overpriced overrated bland tasting food '
#  'like land food place outdated place eat meat serve flavor brisket scale '
#  'onion ordered scale saw amore',
#  'american bar seafood great meal ive crowded night kitchen staff person short '
#  'meal told quality food step particularly like fish chip dripping greasemore',
#  'american cafe diner crystal creek cafe good reputation deserves clearly many '
#  'people agree crowded breakfast welcoming cheerful service quite large '
#  'restaurant booth table tasty pancake bacon could eatmore',
#  'italian pizza vegetarian friendly ok ok ive eaten many many italian '
#  'restaurant would put top vegetarian must admit pia pain however minestrone '
#  'soup homemade delicious papadelli pasta vodka saucedeliziosa tookmore',
#  'american bar pub ordered two gift card phone two week christmas sent email '
#  'december advising never received gift card email answered maria conrow '
#  'stated sorry delay arriving tomorrowmore',
#  'american irish bar great american fare great burger salad wide ranging brew '
#  'menu bottled draft reservation needed busy time noisy somehow go bar scene '
#  'genre friendly prompt service',
#  'american cajun creole vegetarian friendly loved everything restaurant like '
#  'walking magical grotto worth coming usa dish delicious catalan prawn yum '
#  'cauliflower leek asparagus vicyssoise one best thing ever eaten signature '
#  'cocktailmore',
#  'pizza italian bar terrible multiple time used good never go back first wing '
#  'served way used served used come nice sizzle plate themore',
#  'american bar wine bar great place start even finish evening big wine list '
#  'bottle glass loved calamari besides good fresh add avocado pepper radicchio '
#  'real good spicy aioli location historic building aremore',
#  'italian vegetarian friendly vegan option place around since child said never '
#  'quite cared sauce everyone go spaghetti parm like go thursday veal '
#  'scallopini best areamore',
#  'american bar pub travel bit like explore local breweriesale house whatever '
#  'area basically local going know good exception ithaca ale house great '
#  'selcetion local beer wellmore',
#  'american bar pizza cute place big wood fire oven prepare food yes brewery '
#  'kitchen already bonus point got flight upon arriving public offering ne ipa '
#  'orange drip ipa chasing nickel ne session ipamore',
#  'american contemporary vegetarian friendly looking elegant quiet breakfast '
#  'found gray across beautiful park downtown vancouver comfortable enjoyed food',
#  'american bar contemporary son family stayed last weekend two meal dinner '
#  'lunch good food hotel restaurant two meal six adult steak crab risotto crab '
# ...
#  'theyd bring amore',
#  'mexican southwestern latin wife disappointed breakfast home fry potato cold '
#  'like cooked hour ago sat plate ordered egg medium hard came back easy wife '
#  'ordered egg medmore',
#  'american steakhouse bar yakima need eat everything waiter food amazing still '
#  'think good kid macaroni cheese ate son bc slow eating greatmore',
#  'american seafood gluten free option absolutely beautiful dining room tall '
#  'ceiling large chandelier table candelabra celebrating special occasion '
#  'disappointed way',
#  'italian vegetarian friendly gluten free option perfect sunday dinner youre '
#  'looking macaroni gravy pasta sauce without cook alm classic italian dinner '
#  'like grandma made traditional much garlic thank god good italian know '
#  'usemore',
#  'bar pizza american ive lived federal way long time always thought another '
#  'pizza place particular evening thats felt like eating away went holy moley '
#  'yes pizza wonderful style imagine imore',
#  'italian vegetarian friendly gluten free option sunday dinner menu fairly '
#  'extensive service prompt cordial two u veal dish tender could cut fork '
#  'calamari appetizer excellent pistacchio crusted salamon also outstanding '
#  'caesar saald largemore',
#  'american cafe diner lunch spruce goose food tasty enjoyed watching plane '
#  'friendly relaxing',
#  'american steakhouse gluten free option started three cheese garlic bread '
#  'delicious ordered oz prime rib cooked medium twin lobster tail side caesar '
#  'salad loaded baked potato everything ordered delicious',
#  'american cajun creole seafood taste bud could talk would screaming top lung '
#  'happened see place way amarillo always curious try new food cajuncreole '
#  'little place gemmore',
#  'french american cafe enjoying roasted chicken mashed potato cooked perfectly '
#  'great price husband raving garlic spinach alongside tender tasty strip steak '
#  'love coming location breakfast last saturday great also',
#  'chinese asian vegetarian friendly one new time favorite restaurant travel '
#  'seattle went team dinner still fantasize meal staff warm friendly would '
#  'helpful withmore',
#  'mexican spanish vegetarian friendly first time restaurant busy noisy even '
#  'though sat booth ordered drink minute happy hour ended waitress kept saying '
#  'close end happy hour shemore',
#  'american steakhouse gluten free option vic anthony still churning best '
#  'product money buy family standpoint love never ever dissatisfied love dave '
#  'never missing big time',
#  'italian vegetarian friendly gluten free option food fair st best server '
#  'staff really good cheap restaurant mean loud restaurant area hard hold '
#  'conversation',
#  'american cafe contemporary check online see wait time website busy people '
#  'put name go shop come back eat went day busy menu selection notmore',
#  'french bar european first visit started rough cocktail ordered first course '
#  'came ten minute arrived food great main came excellent delicious dorade dish '
#  'star opted formore',
#  'chinese asian vegetarian friendly service weekendsthey usually private party '
#  'going service directed towards thatthats ok saying going weekday get better '
#  'service beenmore',
#  'italian gluten free option vegetarian friendly finally chef know cook '
#  'seafood without getting overdone serf food hot six u delicious meal five '
#  'different entree good beet goat cheese salad many beet wasmore',
#  'american bar vegetarian friendly visit brownsville always meal cheddar menu '
#  'superior variety always competitively priced staff friendly efficient '
#  'healthiest choice vegetable plate includes huge salad cant beat cheddar',
#  'american gluten free option vegetarian friendly daughter went dinner waiter '
#  'new didnt really know menu cook food waiter assisting waiter knowledgeable '
#  'either leaving restaurant got sickmore',
#  'american bar vegetarian friendly recently made business trip yakima stay '
#  'hotel downtown wanted restaurant within walking distance local brew clerk '
#  'recommended second street grill nice place restaurant seating front larger '
#  'bar area rear exposed brickmore',
#  'mexican southwestern latin joined friend late lunch first time second noise '
#  'loud arrived became quieter good variety choose sure surprised didnt bring '
#  'chip salsa hadmore',
#  'asian thai vegan option food amazing everything made scratch service super '
#  'friendly personable',
#  'italian healthy vegetarian friendly delicious food always go place awesome '
#  'italian food nice bottle wine love special menu always delight',
#  'american bar vegetarian friendly place nothing special slow service cooked '
#  'food small portion price youll gasping another drink also nice much better '
#  'place eat drink bellevue one',
#  'peruvian latin seafood food good size dish good bit expensive sice couple '
#  'problem one place order pick dont ready one wait anothermore',
#  'american seafood gluten free option recent dinner poughkeepies bonefish '
#  'grill impressed unusually attentive server well prepared stuffed lobster '
#  'entree surprisingly exceptionally low price point draft beer pint beer '
#  'selection good usually large brewery offering nomore',
#  'pizza fast food vegetarian friendly make sallad pizza pick favourite matter '
#  'end choosing surprised fast served staff friendly service minded',
#  'american southwestern barbecue rudys great always moist brisket perfect '
#  'pulled pork good also sauce good compliment meat cream corn great',
#  'bar vegetarian friendly vegan option pricey delicious food mixed drink good '
#  'small atmosphere dark loud crowded somehow pulled cozy feel despite go '
#  'wallet recovers',
#  'american vegetarian friendly vegan option nice lunch cozy space bit chilly '
#  'day sat great service food would definitely return try something else',
#  'japanese seafood sushi buffet good job sushi asian food american food lot '
#  'option decent price im fan buffet one good worth trying get fresh seafood',
#  'steakhouse argentinean latin hair food told manager said wasnt fault im bald '
#  'kid near food wife restroom',
#  'asian vietnamese vegetarian friendly delightful surprise passing baylor '
#  'territory thought would grab quick bite happened spot blown away delicious '
#  'service quick friendly cant wait visit',
#  'italian vegetarian friendly vegan option kennys italian kitchen great '
#  'restaurant lasagne carbonara best one favorite italian restaurant city',
#  'indian asian vegetarian friendly absolute best indian food ever tandoor '
#  'topli na paneer amazing fine dining great decor fabulous service highly '
#  'recommend',
#  'seafood mediterranean greek going oceanos beginning never bad meal go '
#  'restaurant upscale dining bergen county kumamoto oyster horiatiki salad '
#  'lavraki delicious dessert regular selection recently wemore',
#  'mexican latin spanish food good price charged didnt match menu dont speak '
#  'spanish language problem didnt bother trying ask charged much nice '
#  'atmosphere probably wouldnt recommend unless speak spanish',
#  'american diner vegetarian friendly place almost always busy favorite many '
#  'local others prepared wait go busy everything friend good nice service '
#  'decent price good variety',
#  'italian pizza vegetarian friendly nice pizza ravioli bread delicious wie '
#  'enjoyed eveinig coming back',
#  'italian pizza vegetarian friendly meeting room quiet space large screen tv '
#  'one could cast service good serviced forgotten attentive coffee refill '
#  'appreciated food high quality generous serving size',
#  'american bar barbecue break heart write review must done today february '
#  'decided take wife daughter fat bob smokehouse relaxed valentine dinner wife '
#  'ordered baked haddock wasnt fully cooked daughter orderedmore',
#  'mexican southwestern latin delicious food quick friendly service cant wait '
#  'come back next time drive bellingham',
#  'american bar vegetarian friendly large group ate fish n chip impressed left '
#  'bland flavor nutty manhattan outstanding',
#  'american diner vegetarian friendly fontainbleau diner great nj diner diverse '
#  'menu breakfast day long fry gravy nice addition veggie omelette coffee '
#  'robust lame mudwater like diner always good meal',
#  'american irish bar people lunch menu extensive definitely something everyone '
#  'server attentive friendly check arrived examined quite closely thought cant '
#  'inexpensive definitely return recommend ourmore',
#  'mexican latin spanish business found restaraunt little late leaving laredo '
#  'however may good thing cuz would spent money trying plate wow food authentic '
#  'fresh great tasting pricesmore',
#  'italian vegetarian friendly vegan option thanks server john making first '
#  'first pleasurable one sunday gravy took back time young grandma would make '
#  'best gravy best meat rigatoni favorite date themore',
#  'american wine bar vegetarian friendly brisket superb roughly well worth '
#  'every dollar onlygig seated view nice spacetable designed larger party '
#  'making ackward people either way staff awesome ambiance romanticmore',
#  'mexican southwestern vegetarian friendly waco fabulous restaurant one well '
#  'worth also really super good great food service ambiance around experience '
#  'bring appetite take home split meal portion hugemore',
#  'mediterranean middle eastern vegetarian friendly really great tabouleh salad '
#  'hummus taste dessert keskul fine meant shared eggplant much oil overall '
#  'think presentation fabulous food quality ok',
#  'steakhouse american bar gone year always loved tonight waited minute server '
#  'asking received server apologize wait came extremely sarcastically rude '
#  'askedmore',
#  'american bar brew pub great food great service great atmosphere nacho must '
#  'back',
#  'caribbean jamaican vegetarian friendly make stupid mistake placing nerve '
#  'arguing customer job correctly short african looking bald headed woman',
#  'american wine bar bar wife wine third several time always found place '
#  'convivial food great wine well say name great place',
#  'american bar pub interesting menu full tasty choice good looking pizza '
#  'really wonderful salad beer great well nice place visit',
#  'seafood mediterranean european wife daughter stopped dinner due dietary '
#  'constraint daughter ordered salmon without salt marinade oil waitress '
#  'extremely tentative helpful food arrived daughter could eat salty themore',
#  'american vegetarian friendly vegan option great location main road princeton '
#  'across university great selection pizza many veggie option food delicious '
#  'reasonably priced def come back',
#  'american international vegetarian friendly enjoy going time day lot everyday '
#  'gourmet choice within easy reach step away newly renovated market cafe '
#  'seating area love sushi going early late might notmore',
#  'mexican latin spanish little hide way never even knew puyallup drove past '
#  'placed every day yearfs never courage go finally nerve go inside rough '
#  'insidemore',
#  'italian vegetarian friendly vegan option frequent capital district ny '
#  'ferraris must stop eating every time matter else ive go going im town walk '
#  'hungry there something wrong amount food ismore',
#  'american bar pub sure place star tripadvisor review site maybe beer ok '
#  'better small commercial brewery though ordered range food pub house fry '
#  'quesadilla po town cheesesteakmore',
#  'pizza italian vegetarian friendly say disappointed ordered small margarita '
#  'pizza read glowing review awaiting exceptional pie got average best pizza '
#  'cheese okjust enoughcrust better averagebut important main ingredient '
#  'failedmore',
#  'irish bar pub haileys great irish pub stopped lunch early saturday afternoon '
#  'pleasantly surprised see band setting edition great afternoon live music '
#  'food amazing prime rib delicious asmore',
#  'italian vegetarian friendly gluten free option mother daughter traveled '
#  'white plain st time look pace u went dinner valentine day special menu '
#  'evening mozzarella sausage basil roll appetizer handmade lobster raviolimore',
#  'italian vegetarian friendly vegan option wonderful course italian byo '
#  'experience little disappointed dish others outsdtanding mussel calabria '
#  'chili bland expecting spice lacking flavor kale salad also bland pasta '
#  'dishesmore',
#  'pizza italian vegetarian friendly went wife friend really enjoyed first '
#  'visit best one yet ordered three item calamariwith tentacle large white '
#  'broccoli vodka sauced pie three item excellent sauce themore',
#  'italian vegetarian friendly gluten free option always thrilled meal '
#  'attention received byob joint liquor store right next door selection '
#  'wonderful william favorite server appealing thing willmore',
#  'indian asian vegetarian friendly pure vegetarian hotel edison restaurant '
#  'location good parking facility available food quality average variety food '
#  'option staff service par customer oriented food ordered uber eats door dash',
#  'american vegan option vegetarian friendly great find two u pizza loved crust '
#  'fresh ingredient guy calzones throughly enjoyed well back',
#  'peruvian latin seafood went ceviche good restaurant appealing neighborhood '
#  'also king seedy delivery might better option mind thing',
#  'american mediterranean italian bistro moved elm magnolia went girl brunch '
#  'venue cute food delicious service good although little surprised wouldnt '
#  'split bill',
#  'polish european eastern european absolutely excellent homemade polish food '
#  'surprisingly trentonit like visiting polish grandmother restaurant look '
#  'great outside dont let stop inside beautiful dark wood buttercolored wall '
#  'photo easternmore',
#  'indian vegetarian friendly vegan option seeing great review expected good '
#  'authentic cuisine case ehhhh',
#  'mediterranean greek vegetarian friendly found place accident driving one day '
#  'said try next time went kafe side amazing customer service first walk '
#  'deliciousness food loved itmore',
#  'vegetarian friendly vegan option gluten free option beautifully appointed '
#  'interior outstanding stunning nice garden service great experience slightly '
#  'restricted wine choice coming nj winery must add wine good white late '
#  'harvest dessert seafood andmore',
#  'american southwestern bar dinner burger really good fry nd night tried pork '
#  'taco excellent rusty nail done really well mgr staff accommodating pleasant '
#  'dinner menu much limited thanmore',
#  'american bar seafood came little late wednesday dining room closed lack '
#  'customer seated bar area fine however entirely annoying stuck hitop table '
#  'chair seems amore',
#  'mexican southwestern latin husband moved back upstate ny living yr new '
#  'mexico restaurant come closest close best restaurant frequented nm yes bit '
#  'pricey get pay service fabulousmore',
#  'seafood american international hit miss place feel place overpriced '
#  'considering ambiance food quality party adult placed one booth tight im '
#  'paying upper uppermore',
#  'italian vegetarian friendly vegan option went friend baby around christmas '
#  'server clearly upset told wanted drink coffee couple dessert basically '
#  'dinner still full order took half hour tomore',
#  'american bar vegetarian friendly wait minute get well worth would rate '
#  'salsathe best ever came basket fresh chip fry also would say best havemore',
#  'steakhouse italian bar come brio month good food reasonable price selection '
#  'wine great chain restaurant really like attention kid ask pizza dough play '
#  'makemore',
#  'american vegan option gluten free option stopped yesterday breakfast jersey '
#  'always go taylor ham breakfast ordered egg benedict asked taylor ham meat '
#  'cook taylor ham sliced thin received egg benedictmore',
#  'italian vegetarian friendly vegan option first time dinner couple delicious '
#  'mushroom soup scallop salad appetizer fish main dish creative menu side '
#  'prepared potato crust super short rib excellent daily special tortellini '
#  'stuffed meat outstanding terrific service frequent checkingmore']

# %%
for i in list(np.random.randint(0,len(df_clean),1)):
    print('Original: ', df_clean.iloc[i,7])
    print('Preprocessed: ', df_clean.iloc[i,8])
    print('-'*50)
# Out:
# Original:  indian
# Preprocessed:  vegetarian friendly
# --------------------------------------------------

# %%
for i in list(np.random.randint(0,len(df_clean),1)):
    print('Original: ', df_clean.iloc[i,7])
    print('Preprocessed: ', df_clean.iloc[i,8])
    print('-'*50)
# Out:
# Original:  american
# Preprocessed:  contemporary
# --------------------------------------------------

# %%
df_clean.to_csv('trip_clean.csv', index=False)
data_dump = df_clean.copy()

# %% [markdown]
# ---

# %% [markdown]
# # v. Building a Recommender System

# %%
def get_recommendations(restaurant_type=None, comments=None, city=None, state=None, price=None, num_recommendations=5):
    # Filter restaurants based on multiple inputs
    filtered_restaurants = df_clean.copy()
    if restaurant_type:
        filtered_restaurants = filtered_restaurants[filtered_restaurants['type1'] == restaurant_type]
    if comments:
        filtered_restaurants = filtered_restaurants[filtered_restaurants['comments'].str.contains(comments)]
    if city:
        filtered_restaurants = filtered_restaurants[filtered_restaurants['city'] == city]
    if state:
        filtered_restaurants = filtered_restaurants[filtered_restaurants['state'] == state]
    if price:
        filtered_restaurants = filtered_restaurants[filtered_restaurants['price_range'].isin(price)]

    # Create a new TfidfVectorizer instance
    tfidf_filtered = TfidfVectorizer()
    
    # Fit and transform the filtered data
    tfidf_matrix_filtered = tfidf_filtered.fit_transform(filtered_restaurants['text_preprocessed'])
    
    # Calculate cosine similarity between the filtered restaurants
    cosine_sim_filtered = cosine_similarity(tfidf_matrix_filtered)
    
    # Get the average similarity score for each restaurant
    avg_sim_scores = cosine_sim_filtered.mean(axis=0)
    
    # Get the top N most similar restaurants
    top_recommendations = avg_sim_scores.argsort()[:-num_recommendations-1:-1]
    
    # List of output column to display
    output_col = ['name','street_address','city','state']

    # Update output column into the dataset
    filtered_restaurants = filtered_restaurants[output_col]

    # Create output of the recommended restaurant information
    output = filtered_restaurants.iloc[top_recommendations]

    # Reset the index and drop the old index
    output = output.reset_index(drop=True)

    # Set the index to a new range starting from 1
    output.index = range(1, len(output)+1)

    # Return output
    return output

# %%
# # Example usage:
# restaurant_type = input("Enter restaurant type: ")
# comments = input("Enter keywords or phrases to search for in comments: ")
# city = input("Enter city: ")
# state = input("Enter state: ")

# recommendations = get_recommendations(restaurant_type, comments, city, state, num_recommendations=5)
# display(recommendations)

# %%
def chatbot():
    print("Welcome to the Restaurant Recommendation Chatbot!")
    while True:
        query = input("Press 'Enter' to search restaurant or type 'Quit' to exit: ")
        if query.lower() == 'quit':
            break
        else :
            restaurant_type = input("Enter restaurant type: ")
            comments = input("Enter restaurant ambiance: ")
            city = input("Enter city: ")
            state = input("Enter state: ")
            price = input("Enter price range from 1 to 3: ")
            price_list = [int(x) for x in price.split(',')]
            num_recommendations = int(input("Enter number of recommended restaurant to display: "))
            # confirm = input("Is this correct? (yes/no): ")
            # if confirm.lower() == 'yes':
            #     break
            # else:
            #     print("Please re-enter the information.")
        try:
            recommendations = get_recommendations(restaurant_type, comments, city, state, price_list, num_recommendations)
            print("You might like:")
            display(recommendations)
        except Exception:
            print("Sorry, I couldn't find any recommendations for that restaurant.")
        # except Exception as e:
        #     print("An error occurred:", str(e))

if __name__ == "__main__":
    chatbot()

# %%
# # another recomendation

# data_filter = df_clean.copy()

# select_col = ['name','price_range','reviews','type1','type2','type3','city','street_address','state']

# data_filter = data_filter[select_col]

# def recommend_restaurants(data, query, df_clean, top_n=5):
#     # Preprocess the query
#     query_cleaned = clean_text(query)

#     # TF-IDF Vectorization
#     tfidf_vectorizer = TfidfVectorizer()
#     tfidf_matrix = tfidf_vectorizer.fit_transform(data['text_preprocessed'])

#     # Transform the query to TF-IDF
#     query_tfidf = tfidf_vectorizer.transform([query_cleaned])

#     # Compute cosine similarity
#     cosine_similarities = cosine_similarity(query_tfidf, tfidf_matrix).flatten()

#     # Get top N recommendations
#     top_indices = cosine_similarities.argsort()[-top_n:][::-1]

#     # Create a list to put top restaurants
#     recommend_restaurant = []

#     # Find the top similar restaurants
#     for idx in top_indices:
#         recommend_restaurant.append(data.iloc[idx]['name'])

#     # Creating the new DataFrame with filter
#     dat_for_filter = df_clean[df_clean['name'].isin(recommend_restaurant)]

#     # Print the top similar restaurants
#     print('TOP %s RESTORAN YANG MEMILIKI REVIEW MIRIP DENGAN "%s" : ' % (str(len(recommend_restaurant)), query))

#     return dat_for_filter

# %%
# # Query untuk rekomendasi
# query = "Sushi"

# # Mendapatkan rekomendasi
# recommendations = recommend_restaurants(df_clean, query, data_filter,top_n=10)

# # Menampilkan hasil rekomendasi
# recommendations
